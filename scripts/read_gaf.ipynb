# %%
import os, sys
import urllib
import zipfile
import gzip
import pandas as pd

from collections import defaultdict
from goatools.anno.gaf_reader import GafReader
from goatools.obo_parser import GODag

import networkx as nx

data_dir = "../data/"
# Out:
# /tmp/ipykernel_38418/2207716882.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def download_and_unzip(download_url_link, dir_path, zipped_filename,destination_dir_name, unzip=True):
    #https://www.tutorialsbuddy.com/download-and-unzip-a-zipped-file-in-python
    print("Download starting")

    urllib.request.urlretrieve(
        download_url_link, os.path.join(dir_path, zipped_filename)
    )
    print("Download complete")

    if unzip:
        print("unzipping file starting")
    
        if zipped_filename.endswith(".zip"):
            with zipfile.ZipFile(os.path.join(dir_path, zipped_filename), "r") as zip_file:
                zip_file.extractall(os.path.join(dir_path, destination_dir_name))
        elif zipped_filename.endswith(".gz"):
            print("zipfile")
            with gzip.GzipFile(os.path.join(dir_path, zipped_filename), "rb") as zip_file:
                with open(os.path.join(dir_path, destination_dir_name, zipped_filename.replace(".gz", "")), "wb") as fout:
                    fout.write(zip_file.read())
        else:
            raise NotImplementedError("NO CASE")
            
    
    print("unzipping complete")

# %%
if not os.path.exists(os.path.join(data_dir, "goa_human.gaf")):
    download_and_unzip("http://geneontology.org/gene-associations/goa_human.gaf.gz", ".", os.path.join(data_dir, "goa_human.gaf.gz"), ".")

# %%
if not os.path.exists(os.path.join(data_dir, "go-basic.obo")):
    download_and_unzip("http://geneontology.org/ontology/go-basic.obo", ".", os.path.join(data_dir, "go-basic.obo"), ".", unzip=False)

# %%
genenamesURL = 'https://www.genenames.org/cgi-bin/download/custom?col=gd_hgnc_id&col=gd_app_sym&col=gd_app_name&col=gd_status&col=gd_pub_acc_ids&col=gd_pub_refseq_ids&col=md_prot_id&status=Approved&status=Entry%20Withdrawn&hgnc_dbtag=on&order_by=gd_app_sym_sort&format=text&submit=submit'

if not os.path.exists(os.path.join(data_dir, "hgnc_annot.tsv")):
    download_and_unzip(genenamesURL, ".", os.path.join(data_dir, "hgnc_annot.tsv"), ".", unzip=False)

# %%
ogaf = GafReader(os.path.join(data_dir, "goa_human.gaf"))
obodag = GODag(os.path.join(data_dir, "go-basic.obo"))
# Out:
# HMS:0:00:10.758043 626,136 annotations READ: ../data/goa_human.gaf
# ../data/go-basic.obo: fmt(1.2) rel(2023-01-01) 46,739 Terms

# %%
hgncDF = pd.read_csv(os.path.join(data_dir, "hgnc_annot.tsv"), sep="\t")
uniprot2hgnc = defaultdict(set)
all_genes = set()

for ri, row in hgncDF.iterrows():
    
    status = row["Status"]
    
    if status == "Symbol Withdrawn":
        continue
    
    symbol = row["Approved symbol"]    
    uniprot= row["UniProt ID(supplied by UniProt)"]
    
    all_genes.add(symbol)
    
    if pd.isna(uniprot):
        continue

    uniprot2hgnc[uniprot].add(symbol)

# %%
len(all_genes)
# Out:
# 45406

# %%
go2gene = defaultdict(set)

for assoc in ogaf.get_associations():

    geneID = assoc.DB_ID
    goID = assoc.GO_ID
    
    if not geneID in uniprot2hgnc:
        geneID = assoc.DB_Symbol
        geneIDs = [geneID]
        
        if not geneID in all_genes:
            print(geneID, assoc.Taxon, assoc)
            continue
    else:
        geneIDs = uniprot2hgnc[geneID]
    
    for geneSym in geneIDs:
        go2gene[goID].add((geneSym, tuple(assoc.Qualifier)))
# Out:
# LOC107984156 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JMH3', DB_Symbol='LOC107984156', Qualifier={'enables'}, GO_ID='GO:0003924', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR006689'}, NS='MF', DB_Name={'ARL17 domain-containing protein'}, DB_Synonym={'LOC107984156'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A0G2JMS6 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JMS6', DB_Symbol='A0A0G2JMS6', Qualifier={'enables'}, GO_ID='GO:0004867', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0722'}, NS='MF', DB_Name={'Ovostatin'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A0G2JMS6 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JMS6', DB_Symbol='A0A0G2JMS6', Qualifier={'involved_in'}, GO_ID='GO:0010466', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0646'}, NS='BP', DB_Name={'Ovostatin'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A0G2JMS6 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JMS6', DB_Symbol='A0A0G2JMS6', Qualifier={'located_in'}, GO_ID='GO:0005615', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR011626'}, NS='CC', DB_Name={'Ovostatin'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A0G2JNH3 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JNH3', DB_Symbol='A0A0G2JNH3', Qualifier={'enables'}, GO_ID='GO:0004930', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0297'}, NS='MF', DB_Name={'Olfactory receptor'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A0G2JNH3 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JNH3', DB_Symbol='A0A0G2JNH3', Qualifier={'involved_in'}, GO_ID='GO:0007186', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0297'}, NS='BP', DB_Name={'Olfactory receptor'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A0G2JNH3 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JNH3', DB_Symbol='A0A0G2JNH3', Qualifier={'involved_in'}, GO_ID='GO:0050911', DB_Reference={'GO_REF:0000108'}, Evidence_Code='IEA', With_From={'GO:0004984'}, NS='BP', DB_Name={'Olfactory receptor'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 11), Assigned_By='GOC', Extension=None, Gene_Product_Form_ID=set())
# LOC100653049 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A140TA62', DB_Symbol='LOC100653049', Qualifier={'enables'}, GO_ID='GO:0005198', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR002957'}, NS='MF', DB_Name={'IF rod domain-containing protein'}, DB_Synonym={'LOC100653049'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC100653049 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A140TA62', DB_Symbol='LOC100653049', Qualifier={'located_in'}, GO_ID='GO:0005882', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0403'}, NS='CC', DB_Name={'IF rod domain-containing protein'}, DB_Synonym={'LOC100653049'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC100996750 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A140TA64', DB_Symbol='LOC100996750', Qualifier={'located_in'}, GO_ID='GO:0005829', DB_Reference={'GO_REF:0000117'}, Evidence_Code='IEA', With_From={'ARBA:ARBA00029243'}, NS='CC', DB_Name={'Keratin-associated protein 4-6-like'}, DB_Synonym={'LOC100996750'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC100996750 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A140TA64', DB_Symbol='LOC100996750', Qualifier={'located_in'}, GO_ID='GO:0045095', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR002494'}, NS='CC', DB_Name={'Keratin-associated protein 4-6-like'}, DB_Synonym={'LOC100996750'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC105372440 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTG8', DB_Symbol='LOC105372440', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'ABC transporter permease'}, DB_Synonym={'LOC105372440'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A1B0GTQ1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTQ1', DB_Symbol='A0A1B0GTQ1', Qualifier={'enables'}, GO_ID='GO:0004497', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0503'}, NS='MF', DB_Name={'Cytochrome P450 family 2 subfamily D member 6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A1B0GTQ1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTQ1', DB_Symbol='A0A1B0GTQ1', Qualifier={'enables'}, GO_ID='GO:0005506', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR017972', 'InterPro:IPR001128', 'InterPro:IPR002401', 'InterPro:IPR036396'}, NS='MF', DB_Name={'Cytochrome P450 family 2 subfamily D member 6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A1B0GTQ1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTQ1', DB_Symbol='A0A1B0GTQ1', Qualifier={'enables'}, GO_ID='GO:0016705', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR017972', 'InterPro:IPR001128', 'InterPro:IPR002401', 'InterPro:IPR036396'}, NS='MF', DB_Name={'Cytochrome P450 family 2 subfamily D member 6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A1B0GTQ1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTQ1', DB_Symbol='A0A1B0GTQ1', Qualifier={'enables'}, GO_ID='GO:0020037', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR001128', 'InterPro:IPR002401', 'InterPro:IPR036396'}, NS='MF', DB_Name={'Cytochrome P450 family 2 subfamily D member 6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A1B0GTQ1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTQ1', DB_Symbol='A0A1B0GTQ1', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Cytochrome P450 family 2 subfamily D member 6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC102723971 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GUV8', DB_Symbol='LOC102723971', Qualifier={'enables'}, GO_ID='GO:0036094', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR002345'}, NS='MF', DB_Name={'Lipocln_cytosolic_FA-bd_dom domain-containing protein'}, DB_Synonym={'LOC102723971'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC102723971 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GUV8', DB_Symbol='LOC102723971', Qualifier={'located_in'}, GO_ID='GO:0005576', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0964'}, NS='CC', DB_Name={'Lipocln_cytosolic_FA-bd_dom domain-containing protein'}, DB_Synonym={'LOC102723971'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A1B0GUZ9 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GUZ9', DB_Symbol='A0A1B0GUZ9', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'NADH dehydrogenase subunit 1'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LINC00672 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GWH6', DB_Symbol='LINC00672', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Long intergenic non-protein coding RNA 672'}, DB_Synonym={'LINC00672'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A1W2PRG0 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1W2PRG0', DB_Symbol='A0A1W2PRG0', Qualifier={'located_in'}, GO_ID='GO:0005829', DB_Reference={'GO_REF:0000117'}, Evidence_Code='IEA', With_From={'ARBA:ARBA00029243'}, NS='CC', DB_Name={'glutathione transferase'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A1W2PRN1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1W2PRN1', DB_Symbol='A0A1W2PRN1', Qualifier={'located_in'}, GO_ID='GO:0005794', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR024858'}, NS='CC', DB_Name={'GOLGA2L5 domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A2R8Y4M2 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M2', DB_Symbol='A0A2R8Y4M2', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Small hydrophobic protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC122513141 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M4', DB_Symbol='LOC122513141', Qualifier={'enables'}, GO_ID='GO:0046872', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0479'}, NS='MF', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122513141'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC122513141 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M4', DB_Symbol='LOC122513141', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122513141'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC729966 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y7Y5', DB_Symbol='LOC729966', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Prostate androgen-regulated mucin-like protein 1'}, DB_Synonym={'LOC729966'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC112268384 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YEH3', DB_Symbol='LOC112268384', Qualifier={'enables'}, GO_ID='GO:0004930', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0297'}, NS='MF', DB_Name={'Olfactory receptor'}, DB_Synonym={'LOC112268384'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC112268384 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YEH3', DB_Symbol='LOC112268384', Qualifier={'enables'}, GO_ID='GO:0004984', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR000725'}, NS='MF', DB_Name={'Olfactory receptor'}, DB_Synonym={'LOC112268384'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC112268384 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YEH3', DB_Symbol='LOC112268384', Qualifier={'involved_in'}, GO_ID='GO:0007186', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0297'}, NS='BP', DB_Name={'Olfactory receptor'}, DB_Synonym={'LOC112268384'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC112268384 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YEH3', DB_Symbol='LOC112268384', Qualifier={'involved_in'}, GO_ID='GO:0050911', DB_Reference={'GO_REF:0000108'}, Evidence_Code='IEA', With_From={'GO:0004984'}, NS='BP', DB_Name={'Olfactory receptor'}, DB_Synonym={'LOC112268384'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 11), Assigned_By='GOC', Extension=None, Gene_Product_Form_ID=set())
# LOC112268384 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YEH3', DB_Symbol='LOC112268384', Qualifier={'located_in'}, GO_ID='GO:0005886', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0039'}, NS='CC', DB_Name={'Olfactory receptor'}, DB_Synonym={'LOC112268384'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A2R8YFR7 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YFR7', DB_Symbol='A0A2R8YFR7', Qualifier={'enables'}, GO_ID='GO:0005085', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR001331', 'InterPro:IPR000219'}, NS='MF', DB_Name={'DH domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A2R8YFR7 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YFR7', DB_Symbol='A0A2R8YFR7', Qualifier={'involved_in'}, GO_ID='GO:0035556', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR001331'}, NS='BP', DB_Name={'DH domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC112694756 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2U3TZM8', DB_Symbol='LOC112694756', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Protein FAM189B'}, DB_Synonym={'LOC112694756'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A494C0I6 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A494C0I6', DB_Symbol='A0A494C0I6', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Secreted protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC728392 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A494C1I1', DB_Symbol='LOC728392', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'CLN6 transmembrane ER protein'}, DB_Synonym={'LOC728392'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A499FJF3 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A499FJF3', DB_Symbol='A0A499FJF3', Qualifier={'involved_in'}, GO_ID='GO:0007165', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR000198'}, NS='BP', DB_Name={'Rho-GAP domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A0A7I2V2S6 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7I2V2S6', DB_Symbol='A0A7I2V2S6', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'ORF6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC122319436 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7I2V3R4', DB_Symbol='LOC122319436', Qualifier={'enables'}, GO_ID='GO:0046872', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0479'}, NS='MF', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122319436'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC122319436 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7I2V3R4', DB_Symbol='LOC122319436', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122319436'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC122539214 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7P0TAN4', DB_Symbol='LOC122539214', Qualifier={'enables'}, GO_ID='GO:0046872', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0479'}, NS='MF', DB_Name={'Zinc finger protein 160-like'}, DB_Synonym={'LOC122539214'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# LOC122539214 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7P0TAN4', DB_Symbol='LOC122539214', Qualifier={'involved_in'}, GO_ID='GO:0006355', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR001909', 'InterPro:IPR036051'}, NS='BP', DB_Name={'Zinc finger protein 160-like'}, DB_Synonym={'LOC122539214'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC400499 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A8Q3SIG1', DB_Symbol='LOC400499', Qualifier={'enables'}, GO_ID='GO:0005319', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR015816', 'InterPro:IPR015817', 'InterPro:IPR015255', 'InterPro:IPR001747', 'InterPro:IPR015819'}, NS='MF', DB_Name={'Vitellogenin domain-containing protein'}, DB_Synonym={'LOC400499'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# LOC400499 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A8Q3SIG1', DB_Symbol='LOC400499', Qualifier={'involved_in'}, GO_ID='GO:0006869', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0445'}, NS='BP', DB_Name={'Vitellogenin domain-containing protein'}, DB_Synonym={'LOC400499'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A0A8Q3SIZ7 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A8Q3SIZ7', DB_Symbol='A0A8Q3SIZ7', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0472'}, NS='CC', DB_Name={'Transmembrane protein 218'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# XKRY2 [9606] ntgafobj(DB='UniProtKB', DB_ID='A2RUG3', DB_Symbol='XKRY2', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0162'}, NS='CC', DB_Name={'Testis-specific XK-related protein, Y-linked 2'}, DB_Synonym={'XKRY2'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A6NDX4 [9606] ntgafobj(DB='UniProtKB', DB_ID='A6NDX4', DB_Symbol='A6NDX4', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0162'}, NS='CC', DB_Name={'Putative transmembrane protein ENSP00000320207'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# NPEPPSL1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A6NEC2', DB_Symbol='NPEPPSL1', Qualifier={'located_in'}, GO_ID='GO:0070062', DB_Reference={'PMID:23533145'}, Evidence_Code='HDA', With_From=set(), NS='CC', DB_Name={'Puromycin-sensitive aminopeptidase-like protein'}, DB_Synonym={'NPEPPSL1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2014, 7, 14), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A6NJR5 [9606] ntgafobj(DB='UniProtKB', DB_ID='A6NJR5', DB_Symbol='A6NJR5', Qualifier={'involved_in'}, GO_ID='GO:0045737', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR020984'}, NS='BP', DB_Name={'Putative speedy protein-like protein 3'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# A6NNC1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A6NNC1', DB_Symbol='A6NNC1', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0162'}, NS='CC', DB_Name={'Putative POM121-like protein 1-like'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A8MTW9 [9606] ntgafobj(DB='UniProtKB', DB_ID='A8MTW9', DB_Symbol='A8MTW9', Qualifier={'located_in'}, GO_ID='GO:0005576', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0243'}, NS='CC', DB_Name={'Putative uncharacterized protein ENSP00000380674'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# A8MUN3 [9606] ntgafobj(DB='UniProtKB', DB_ID='A8MUN3', DB_Symbol='A8MUN3', Qualifier={'located_in'}, GO_ID='GO:0005576', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0243'}, NS='CC', DB_Name={'Putative uncharacterized protein ENSP00000381830'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# B2RBV5 [9606] ntgafobj(DB='UniProtKB', DB_ID='B2RBV5', DB_Symbol='B2RBV5', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:24248101'}, Evidence_Code='IPI', With_From={'UniProtKB:O14519'}, NS='MF', DB_Name={'Putative MORF4 family-associated protein 1-like protein UPP'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2015, 9, 1), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# B2RBV5 [9606] ntgafobj(DB='UniProtKB', DB_ID='B2RBV5', DB_Symbol='B2RBV5', Qualifier={'involved_in'}, GO_ID='GO:0051726', DB_Reference={'PMID:24248101'}, Evidence_Code='IDA', With_From=set(), NS='BP', DB_Name={'Putative MORF4 family-associated protein 1-like protein UPP'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2019, 11, 6), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# C0HLV8 [9606] ntgafobj(DB='UniProtKB', DB_ID='C0HLV8', DB_Symbol='C0HLV8', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:33406399'}, Evidence_Code='IPI', With_From={'UniProtKB:P00338'}, NS='MF', DB_Name={'PTEN upstream open reading frame MP31'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 3, 10), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# C0HLV8 [9606] ntgafobj(DB='UniProtKB', DB_ID='C0HLV8', DB_Symbol='C0HLV8', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:33406399'}, Evidence_Code='IPI', With_From={'UniProtKB:P07195'}, NS='MF', DB_Name={'PTEN upstream open reading frame MP31'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 3, 10), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# C0HLV8 [9606] ntgafobj(DB='UniProtKB', DB_ID='C0HLV8', DB_Symbol='C0HLV8', Qualifier={'involved_in'}, GO_ID='GO:0019516', DB_Reference={'PMID:33406399'}, Evidence_Code='IMP', With_From=set(), NS='BP', DB_Name={'PTEN upstream open reading frame MP31'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 3, 10), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# C0HLV8 [9606] ntgafobj(DB='UniProtKB', DB_ID='C0HLV8', DB_Symbol='C0HLV8', Qualifier={'located_in'}, GO_ID='GO:0005739', DB_Reference={'PMID:33406399'}, Evidence_Code='IDA', With_From=set(), NS='CC', DB_Name={'PTEN upstream open reading frame MP31'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 3, 10), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# C22orf46 [9606] ntgafobj(DB='UniProtKB', DB_ID='C9J442', DB_Symbol='C22orf46', Qualifier={'located_in'}, GO_ID='GO:0005576', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0243'}, NS='CC', DB_Name={'Uncharacterized protein C22orf46'}, DB_Synonym={'C22orf46'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# CNK3/IPCEF1 [9606] ntgafobj(DB='UniProtKB', DB_ID='G9CGD6', DB_Symbol='CNK3/IPCEF1', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:22085542'}, Evidence_Code='IPI', With_From={'UniProtKB:Q99418'}, NS='MF', DB_Name={'CNK3/IPCEF1 fusion protein'}, DB_Synonym={'CNK3/IPCEF1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2018, 10, 5), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# CNK3/IPCEF1 [9606] ntgafobj(DB='UniProtKB', DB_ID='G9CGD6', DB_Symbol='CNK3/IPCEF1', Qualifier={'involved_in'}, GO_ID='GO:0009966', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR010599'}, NS='BP', DB_Name={'CNK3/IPCEF1 fusion protein'}, DB_Synonym={'CNK3/IPCEF1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# CNK3/IPCEF1 [9606] ntgafobj(DB='UniProtKB', DB_ID='G9CGD6', DB_Symbol='CNK3/IPCEF1', Qualifier={'involved_in'}, GO_ID='GO:2001114', DB_Reference={'PMID:22085542'}, Evidence_Code='IMP', With_From=set(), NS='BP', DB_Name={'CNK3/IPCEF1 fusion protein'}, DB_Synonym={'CNK3/IPCEF1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2018, 10, 8), Assigned_By='UniProt', Extension=<goatools.anno.extensions.extensions.AnnotationExtensions object at 0x7fdac9215ed0>, Gene_Product_Form_ID=set())
# CNK3/IPCEF1 [9606] ntgafobj(DB='UniProtKB', DB_ID='G9CGD6', DB_Symbol='CNK3/IPCEF1', Qualifier={'located_in'}, GO_ID='GO:0005737', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR010599'}, NS='CC', DB_Name={'CNK3/IPCEF1 fusion protein'}, DB_Synonym={'CNK3/IPCEF1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# CNK3/IPCEF1 [9606] ntgafobj(DB='UniProtKB', DB_ID='G9CGD6', DB_Symbol='CNK3/IPCEF1', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR010599'}, NS='CC', DB_Name={'CNK3/IPCEF1 fusion protein'}, DB_Synonym={'CNK3/IPCEF1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'enables'}, GO_ID='GO:0003723', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0694'}, NS='MF', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'enables'}, GO_ID='GO:0003964', DB_Reference={'PMID:7516468'}, Evidence_Code='IDA', With_From=set(), NS='MF', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2013, 11, 14), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'enables'}, GO_ID='GO:0009036', DB_Reference={'PMID:8945517'}, Evidence_Code='IDA', With_From=set(), NS='MF', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2013, 11, 13), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'enables'}, GO_ID='GO:0046872', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0479'}, NS='MF', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'involved_in'}, GO_ID='GO:0006310', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0233'}, NS='BP', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'involved_in'}, GO_ID='GO:0032197', DB_Reference={'PMID:8945517'}, Evidence_Code='IMP', With_From=set(), NS='BP', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2013, 11, 13), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'involved_in'}, GO_ID='GO:0032199', DB_Reference={'PMID:7516468'}, Evidence_Code='IDA', With_From=set(), NS='BP', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2013, 11, 14), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# O00370 [9606] ntgafobj(DB='UniProtKB', DB_ID='O00370', DB_Symbol='O00370', Qualifier={'involved_in'}, GO_ID='GO:0090305', DB_Reference={'PMID:8945517'}, Evidence_Code='IDA', With_From=set(), NS='BP', DB_Name={'LINE-1 retrotransposable element ORF2 protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2013, 11, 13), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# CXorf1 [9606] ntgafobj(DB='UniProtKB', DB_ID='O96002', DB_Symbol='CXorf1', Qualifier={'enables'}, GO_ID='GO:0003674', DB_Reference={'GO_REF:0000015'}, Evidence_Code='ND', With_From=set(), NS='MF', DB_Name={'Putative transmembrane protein CXorf1'}, DB_Synonym={'CXorf1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2006, 10, 26), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# CXorf1 [9606] ntgafobj(DB='UniProtKB', DB_ID='O96002', DB_Symbol='CXorf1', Qualifier={'involved_in'}, GO_ID='GO:0008150', DB_Reference={'GO_REF:0000015'}, Evidence_Code='ND', With_From=set(), NS='BP', DB_Name={'Putative transmembrane protein CXorf1'}, DB_Synonym={'CXorf1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2006, 10, 26), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# CXorf1 [9606] ntgafobj(DB='UniProtKB', DB_ID='O96002', DB_Symbol='CXorf1', Qualifier={'is_active_in'}, GO_ID='GO:0005575', DB_Reference={'GO_REF:0000015'}, Evidence_Code='ND', With_From=set(), NS='CC', DB_Name={'Putative transmembrane protein CXorf1'}, DB_Synonym={'CXorf1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2006, 10, 26), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# CXorf1 [9606] ntgafobj(DB='UniProtKB', DB_ID='O96002', DB_Symbol='CXorf1', Qualifier={'located_in'}, GO_ID='GO:0016020', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0162'}, NS='CC', DB_Name={'Putative transmembrane protein CXorf1'}, DB_Synonym={'CXorf1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:25416956'}, Evidence_Code='IPI', With_From={'UniProtKB:Q93062'}, NS='MF', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 12), Assigned_By='IntAct', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:32814053'}, Evidence_Code='IPI', With_From={'UniProtKB:O76024'}, NS='MF', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 12), Assigned_By='IntAct', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:32814053'}, Evidence_Code='IPI', With_From={'UniProtKB:P07339'}, NS='MF', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 12), Assigned_By='IntAct', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:32814053'}, Evidence_Code='IPI', With_From={'UniProtKB:P28799'}, NS='MF', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 12), Assigned_By='IntAct', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:32814053'}, Evidence_Code='IPI', With_From={'UniProtKB:P28799-2'}, NS='MF', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 12), Assigned_By='IntAct', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'enables'}, GO_ID='GO:0005515', DB_Reference={'PMID:32814053'}, Evidence_Code='IPI', With_From={'UniProtKB:Q13148'}, NS='MF', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 12), Assigned_By='IntAct', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'involved_in'}, GO_ID='GO:0008150', DB_Reference={'GO_REF:0000015'}, Evidence_Code='ND', With_From=set(), NS='BP', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2006, 10, 26), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# GIG44 [9606] ntgafobj(DB='UniProtKB', DB_ID='P09565', DB_Symbol='GIG44', Qualifier={'is_active_in'}, GO_ID='GO:0005575', DB_Reference={'GO_REF:0000015'}, Evidence_Code='ND', With_From=set(), NS='CC', DB_Name={'Putative insulin-like growth factor 2-associated protein'}, DB_Synonym={'GIG44', 'PP9974'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2006, 10, 26), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61574', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0003723', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0694'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Rec protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61574', DB_Symbol='HERVK_113', Qualifier={'involved_in'}, GO_ID='GO:0051028', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0509'}, NS='BP', DB_Name={'Endogenous retrovirus group K member 113 Rec protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61574', DB_Symbol='HERVK_113', Qualifier={'located_in'}, GO_ID='GO:0005730', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0188'}, NS='CC', DB_Name={'Endogenous retrovirus group K member 113 Rec protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61574', DB_Symbol='HERVK_113', Qualifier={'located_in'}, GO_ID='GO:0005737', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0086'}, NS='CC', DB_Name={'Endogenous retrovirus group K member 113 Rec protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61576', DB_Symbol='HERV-K104', Qualifier={'enables'}, GO_ID='GO:0003723', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0694'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 104 Rec protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61576', DB_Symbol='HERV-K104', Qualifier={'involved_in'}, GO_ID='GO:0051028', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0509'}, NS='BP', DB_Name={'Endogenous retrovirus group K member 104 Rec protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61576', DB_Symbol='HERV-K104', Qualifier={'located_in'}, GO_ID='GO:0005730', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0188'}, NS='CC', DB_Name={'Endogenous retrovirus group K member 104 Rec protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P61576', DB_Symbol='HERV-K104', Qualifier={'located_in'}, GO_ID='GO:0005737', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0086'}, NS='CC', DB_Name={'Endogenous retrovirus group K member 104 Rec protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P62684', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0003676', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR036875', 'InterPro:IPR001878'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Gag polyprotein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P62684', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0005198', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR003322'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Gag polyprotein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P62684', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0008270', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR036875', 'InterPro:IPR001878'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Gag polyprotein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P62684', DB_Symbol='HERVK_113', Qualifier={'involved_in'}, GO_ID='GO:0016032', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR008919', 'InterPro:IPR000721'}, NS='BP', DB_Name={'Endogenous retrovirus group K member 113 Gag polyprotein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P62684', DB_Symbol='HERVK_113', Qualifier={'located_in'}, GO_ID='GO:0005886', DB_Reference={'GO_REF:0000044'}, Evidence_Code='IEA', With_From={'UniProtKB-SubCell:SL-0039'}, NS='CC', DB_Name={'Endogenous retrovirus group K member 113 Gag polyprotein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63121', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0003676', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR000467'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Pro protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63121', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0004190', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0064'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Pro protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63121', DB_Symbol='HERVK_113', Qualifier={'involved_in'}, GO_ID='GO:0006508', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0645'}, NS='BP', DB_Name={'Endogenous retrovirus group K member 113 Pro protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63124', DB_Symbol='HERV-K104', Qualifier={'enables'}, GO_ID='GO:0003676', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR000467'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 104 Pro protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63124', DB_Symbol='HERV-K104', Qualifier={'enables'}, GO_ID='GO:0004190', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0064'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 104 Pro protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERV-K104 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63124', DB_Symbol='HERV-K104', Qualifier={'involved_in'}, GO_ID='GO:0006508', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0645'}, NS='BP', DB_Name={'Endogenous retrovirus group K member 104 Pro protein'}, DB_Synonym={'HERV-K104'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63132', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0003677', DB_Reference={'GO_REF:0000043'}, Evidence_Code='IEA', With_From={'UniProtKB-KW:KW-0238'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Pol protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63132', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0003964', DB_Reference={'GO_REF:0000003'}, Evidence_Code='IEA', With_From={'EC:2.7.7.49'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Pol protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63132', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0004523', DB_Reference={'GO_REF:0000003'}, Evidence_Code='IEA', With_From={'EC:3.1.26.4'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Pol protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='UniProt', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63132', DB_Symbol='HERVK_113', Qualifier={'enables'}, GO_ID='GO:0008270', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR003308'}, NS='MF', DB_Name={'Endogenous retrovirus group K member 113 Pol protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# HERVK_113 [9606] ntgafobj(DB='UniProtKB', DB_ID='P63132', DB_Symbol='HERVK_113', Qualifier={'involved_in'}, GO_ID='GO:0006278', DB_Reference={'GO_REF:0000002'}, Evidence_Code='IEA', With_From={'InterPro:IPR010661'}, NS='BP', DB_Name={'Endogenous retrovirus group K member 113 Pol protein'}, DB_Synonym={'HERVK_113'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 11, 9), Assigned_By='InterPro', Extension=None, Gene_Product_Form_ID=set())
# ...
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='Q3C1V9', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0006826', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:P02786', 'PANTHER:PTN002572056'}, NS='BP', DB_Name={'Putative uncharacterized protein ENSP00000334305'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2019, 5, 6), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZN92', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0006226', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'RGD:620849', 'PANTHER:PTN000133341', 'UniProtKB:O34919', 'UniProtKB:P06968'}, NS='BP', DB_Name={"Putative inactive deoxyuridine 5'-triphosphate nucleotidohydrolase-like protein FLJ16323"}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 8, 7), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# ACOT7L [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZUV0', DB_Symbol='ACOT7L', Qualifier={'enables'}, GO_ID='GO:0036042', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000114372', 'UniProtKB:O00154'}, NS='MF', DB_Name={'Putative cytosolic acyl coenzyme A thioester hydrolase-like'}, DB_Synonym={'ACOT7L', 'BACHL'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2018, 4, 11), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC112267897 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A3B3IRQ3', DB_Symbol='LOC112267897', Qualifier={'involved_in'}, GO_ID='GO:0001942', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:2157767', 'PANTHER:PTN002526071'}, NS='BP', DB_Name={'Keratin-associated protein 21-1-like'}, DB_Synonym={'LOC112267897'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 9, 17), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC102724159 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0B4J2E5', DB_Symbol='LOC102724159', Qualifier={'part_of'}, GO_ID='GO:0034388', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000458249', 'SGD:S000000653'}, NS='CC', DB_Name={'Periodic tryptophan protein 2 homolog'}, DB_Synonym={'PTN002323483', 'UniProtKB:A0A0B4J2E5'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 2, 28), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZN92', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0046081', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000133341', 'RGD:620849', 'UniProtKB:P06968', 'UniProtKB:O34919', 'SGD:S000000456'}, NS='BP', DB_Name={"Putative inactive deoxyuridine 5'-triphosphate nucleotidohydrolase-like protein FLJ16323"}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 8, 7), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# ACOT7L [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZUV0', DB_Symbol='ACOT7L', Qualifier={'involved_in'}, GO_ID='GO:0006637', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000114372', 'UniProtKB:O00154', 'UniProtKB:P0A8Z0'}, NS='BP', DB_Name={'Putative cytosolic acyl coenzyme A thioester hydrolase-like'}, DB_Synonym={'ACOT7L', 'BACHL'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 11, 10), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GTQ1', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0019369', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000670525', 'RGD:620640'}, NS='BP', DB_Name={'Cytochrome P450 family 2 subfamily D member 6'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 2, 28), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZN92', DB_Symbol='', Qualifier={'enables'}, GO_ID='GO:0004170', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000133341', 'FB:FBgn0250837', 'UniProtKB:P9WNS5', 'RGD:620849', 'CGD:CAL0000195525', 'UniProtKB:P06968', 'UniProtKB:P33316', 'UniProtKB:O34919', 'SGD:S000000456', 'dictyBase:DDB_G0293374'}, NS='MF', DB_Name={"Putative inactive deoxyuridine 5'-triphosphate nucleotidohydrolase-like protein FLJ16323"}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 12, 15), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC100653049 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A140TA62', DB_Symbol='LOC100653049', Qualifier={'involved_in'}, GO_ID='GO:0045109', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:P35900', 'MGI:MGI:96691', 'UniProtKB:P02533', 'MGI:MGI:1918060', 'UniProtKB:P35527', 'MGI:MGI:96685', 'PANTHER:PTN008383948', 'MGI:MGI:1914059'}, NS='BP', DB_Name={'IF rod domain-containing protein'}, DB_Synonym={'LOC100653049'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 10, 8), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC122513141 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M4', DB_Symbol='LOC122513141', Qualifier={'involved_in'}, GO_ID='GO:0051865', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000419843', 'UniProtKB:Q9NXI6'}, NS='BP', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122513141'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2018, 9, 18), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JRQ6', DB_Symbol='', Qualifier={'is_active_in'}, GO_ID='GO:0005615', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000587099', 'UniProtKB:P01619'}, NS='CC', DB_Name={'Ig-like domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 8, 9), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YE69', DB_Symbol='', Qualifier={'is_active_in'}, GO_ID='GO:0005789', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:Q5JRA6', 'MGI:MGI:2443183', 'PANTHER:PTN000570072'}, NS='CC', DB_Name={'MIA SH3 domain ER export factor 2'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 4, 28), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YE69', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0009306', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'FB:FBgn0286898', 'PANTHER:PTN000570072'}, NS='BP', DB_Name={'MIA SH3 domain ER export factor 2'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 4, 28), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC122513141 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M4', DB_Symbol='LOC122513141', Qualifier={'involved_in'}, GO_ID='GO:0035519', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000419843', 'UniProtKB:Q9NXI6'}, NS='BP', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122513141'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2018, 9, 18), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# BARGIN [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZT62', DB_Symbol='BARGIN', Qualifier={'involved_in'}, GO_ID='GO:0035020', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN001797409', 'MGI:MGI:2144423'}, NS='BP', DB_Name={'Bargin'}, DB_Synonym={'BARGIN'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 9, 22), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='C9JQL5', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0051607', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:1915963', 'MGI:MGI:1933382', 'MGI:MGI:1913391', 'UniProtKB:Q01628', 'PANTHER:PTN000360680'}, NS='BP', DB_Name={'Putative dispanin subfamily A member 2d'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 5, 2), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC102723971 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A1B0GUV8', DB_Symbol='LOC102723971', Qualifier={'is_active_in'}, GO_ID='GO:0005615', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'RGD:708506', 'RGD:3433', 'UniProtKB:P41222', 'UniProtKB:H2B3G5', 'PANTHER:PTN001350062', 'UniProtKB:P80188', 'UniProtKB:P31025', 'MGI:MGI:97234', 'MGI:MGI:96757', 'MGI:MGI:97236', 'MGI:MGI:2387617', 'MGI:MGI:3709619', 'MGI:MGI:97235', 'MGI:MGI:97233', 'RGD:69408'}, NS='CC', DB_Name={'Lipocln_cytosolic_FA-bd_dom domain-containing protein'}, DB_Synonym={'LOC102723971'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 10, 7), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='C9JQL5', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0045071', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:Q01629', 'PANTHER:PTN000360680', 'UniProtKB:P13164', 'UniProtKB:Q01628'}, NS='BP', DB_Name={'Putative dispanin subfamily A member 2d'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2017, 5, 2), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0J9YWU9', DB_Symbol='', Qualifier={'is_active_in'}, GO_ID='GO:0009897', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN001510949', 'MGI:MGI:99546', 'MGI:MGI:96447'}, NS='CC', DB_Name={'Ig-like domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 10, 8), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC122513141 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M4', DB_Symbol='LOC122513141', Qualifier={'involved_in'}, GO_ID='GO:0070585', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN000419843', 'UniProtKB:Q9NXI6'}, NS='BP', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122513141'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2018, 9, 18), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC122319436 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7I2V3R4', DB_Symbol='LOC122319436', Qualifier={'enables'}, GO_ID='GO:0061630', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:1923322', 'UniProtKB:Q96D59', 'PANTHER:PTN001866205'}, NS='MF', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122319436'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 8, 19), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0J9YY99', DB_Symbol='', Qualifier={'is_active_in'}, GO_ID='GO:0009897', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN001510949', 'MGI:MGI:99546', 'MGI:MGI:96447'}, NS='CC', DB_Name={'Ig-like domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2022, 10, 8), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='C9JQL5', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0035456', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:Q01629', 'PANTHER:PTN000360680', 'UniProtKB:P13164', 'UniProtKB:Q01628'}, NS='BP', DB_Name={'Putative dispanin subfamily A member 2d'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 5, 30), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A0G2JRQ6', DB_Symbol='', Qualifier={'involved_in'}, GO_ID='GO:0006955', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:98936', 'PANTHER:PTN000587099', 'UniProtKB:P01619'}, NS='BP', DB_Name={'Ig-like domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 8, 9), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC122513141 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8Y4M4', DB_Symbol='LOC122513141', Qualifier={'enables'}, GO_ID='GO:0061630', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:1923322', 'UniProtKB:Q96D59', 'PANTHER:PTN001866205'}, NS='MF', DB_Name={'RING-type domain-containing protein'}, DB_Synonym={'LOC122513141'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 8, 19), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# BARGIN [9606] ntgafobj(DB='UniProtKB', DB_ID='Q6ZT62', DB_Symbol='BARGIN', Qualifier={'involved_in'}, GO_ID='GO:0043547', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'PANTHER:PTN002680027', 'UniProtKB:Q9Y3L3', 'MGI:MGI:104603', 'RGD:1306275', 'UniProtKB:Q6ZT62'}, NS='BP', DB_Name={'Bargin'}, DB_Synonym={'BARGIN'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 9, 30), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# NPEPPSL1 [9606] ntgafobj(DB='UniProtKB', DB_ID='A6NEC2', DB_Symbol='NPEPPSL1', Qualifier={'is_active_in'}, GO_ID='GO:0005737', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:P55786', 'PomBase:SPBC1921.05', 'UniProtKB:P15144', 'MGI:MGI:2387123', 'MGI:MGI:106645', 'SGD:S000001399', 'PANTHER:PTN000164250', 'RGD:708542', 'RGD:621752', 'MGI:MGI:1933403', 'dictyBase:DDB_G0270994', 'UniProtKB:Q6P179', 'WB:WBGene00003914', 'FB:FBgn0039640'}, NS='CC', DB_Name={'Puromycin-sensitive aminopeptidase-like protein'}, DB_Synonym={'NPEPPSL1'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 11, 10), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC647264 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A3B3IRS2', DB_Symbol='LOC647264', Qualifier={'involved_in'}, GO_ID='GO:0001942', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:2157767', 'PANTHER:PTN002526071'}, NS='BP', DB_Name={'Keratin-associated protein 21-1-like'}, DB_Synonym={'LOC647264'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 9, 17), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC122539214 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A7P0TAN4', DB_Symbol='LOC122539214', Qualifier={'enables'}, GO_ID='GO:0001228', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'MGI:MGI:95457', 'MGI:MGI:1917923', 'WB:WBGene00003015', 'PomBase:SPAC4G8.13c', 'PANTHER:PTN002811836'}, NS='MF', DB_Name={'Zinc finger protein 160-like'}, DB_Synonym={'LOC122539214'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 11, 12), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
#  [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A2R8YFR7', DB_Symbol='', Qualifier={'is_active_in'}, GO_ID='GO:0005634', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:Q12774', 'PANTHER:PTN002656143'}, NS='CC', DB_Name={'DH domain-containing protein'}, DB_Synonym=set(), DB_Type='protein', Taxon=[9606], Date=datetime.date(2020, 4, 14), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())
# LOC102723996 [9606] ntgafobj(DB='UniProtKB', DB_ID='A0A087X1L8', DB_Symbol='LOC102723996', Qualifier={'involved_in'}, GO_ID='GO:0001817', DB_Reference={'PMID:21873635'}, Evidence_Code='IBA', With_From={'UniProtKB:Q5ZPR3', 'PANTHER:PTN008605761', 'MGI:MGI:3606486', 'UniProtKB:P78410', 'UniProtKB:Q9UM44', 'UniProtKB:O00481', 'MGI:MGI:1354701', 'MGI:MGI:1859549', 'MGI:MGI:2183926', 'MGI:MGI:3039619', 'MGI:MGI:103118'}, NS='BP', DB_Name={'ICOS ligand'}, DB_Synonym={'UniProtKB:A0A087X1L8', 'PTN002816535'}, DB_Type='protein', Taxon=[9606], Date=datetime.date(2021, 5, 31), Assigned_By='GO_Central', Extension=None, Gene_Product_Form_ID=set())

# %%
g = nx.DiGraph()

# %%
for gene in all_genes:
    g.add_node(gene, type="gene", score=0)

# %%
obodag["GO:0006915"]
# Out:
# GOTerm('GO:0006915'):
#   id:GO:0006915
#   item_id:GO:0006915
#   name:apoptotic process
#   namespace:biological_process
#   _parents: 1 items
#     GO:0012501
#   parents: 1 items
#     GO:0012501	level-03	depth-03	programmed cell death [biological_process]
#   children: 18 items
#   level:4
#   depth:4
#   is_obsolete:False
#   alt_ids: 2 items
#     GO:0006917
#     GO:0008632

# %%
#add all nodes with attributes
for goEntry in obodag:
    
    termID = goEntry
    termObj = obodag[goEntry]
    
    if termObj.is_obsolete:
        continue
    
    termName = termObj.name
    termNS = termObj.namespace
    
    g.add_node(termID, id=termID, name=termName, ns=termNS, score=0)
    
for goEntry in obodag:
    
    termID = goEntry
    termObj = obodag[goEntry]
    
    for child in termObj.children:
        if child in g.nodes and not (child, goEntry) in g.edges:
            g.add_edge(child, goEntry, type="part_of", score=0)
            
    for parent in termObj.parents:
        if parent.id in g.nodes and not (goEntry, parent.id) in g.edges:
            g.add_edge(goEntry, parent.id, type="part_of", score=0)

# %%
print(g)
# Out:
# DiGraph with 92145 nodes and 74934 edges

# %%
[x for x in g.nodes][:5]
# Out:
# ['SBK2', 'LIM2-AS1', 'ROPN1L', 'LINC01341', 'MIR518E']

# %%
all_interactions = set()
for goID in list(go2gene):   
    for gene, interaction in go2gene[goID]:
        for x in interaction:
            all_interactions.add(x)
all_interactions
# Out:
# {'NOT',
#  'acts_upstream_of',
#  'acts_upstream_of_negative_effect',
#  'acts_upstream_of_or_within',
#  'acts_upstream_of_or_within_negative_effect',
#  'acts_upstream_of_or_within_positive_effect',
#  'acts_upstream_of_positive_effect',
#  'colocalizes_with',
#  'contributes_to',
#  'enables',
#  'involved_in',
#  'is_active_in',
#  'located_in',
#  'part_of'}

# %%
interaction_harmonize = {
    'NOT': "interacts",
    'acts_upstream_of': "interacts",
    'acts_upstream_of_negative_effect': "interacts",
    'acts_upstream_of_or_within': "interacts",
    'acts_upstream_of_or_within_negative_effect': "interacts",
    'acts_upstream_of_or_within_positive_effect': "interacts",
    'acts_upstream_of_positive_effect': "interacts",
    'colocalizes_with': "interacts",
    'contributes_to': "activates",
    'enables': "activates",
    'involved_in': "activates",
    'is_active_in': "activates",
    'located_in': "interacts",
    'part_of': "interacts"
    }

# %%
for goID in list(go2gene)[:5]:
    print(goID, go2gene[goID])
    
    for gene, interaction in go2gene[goID]:
        g.add_edge( gene, goID, type=interaction_harmonize[interaction[0]], go_interaction = interaction[0])
# Out:
# GO:0003723 {('SETX', ('enables',)), ('USP17L27', ('enables',)), ('RSRC2', ('enables',)), ('THUMPD1', ('enables',)), ('IMPDH1', ('enables',)), ('NOLC1', ('enables',)), ('H1-5', ('enables',)), ('TIA1', ('enables',)), ('NVL', ('enables',)), ('SCAF1', ('enables',)), ('RPL30', ('enables',)), ('SUPT16H', ('enables',)), ('APOBEC3A', ('enables',)), ('EIF1', ('enables',)), ('SURF6', ('enables',)), ('KYAT3', ('enables',)), ('DDX20', ('enables',)), ('RPS15A', ('enables',)), ('TES', ('enables',)), ('TFRC', ('enables',)), ('UTP23', ('enables',)), ('EIF3CL', ('enables',)), ('MRPS9', ('enables',)), ('FKBP3', ('enables',)), ('SERPINH1', ('enables',)), ('NXF2', ('enables',)), ('FUBP1', ('enables',)), ('EIF5AL1', ('enables',)), ('TSN', ('enables',)), ('HSPB1', ('enables',)), ('YTHDF1', ('enables',)), ('PPP1R8', ('enables',)), ('YWHAG', ('enables',)), ('SECISBP2L', ('enables',)), ('RPS5', ('enables',)), ('SRPK2', ('enables',)), ('CNOT1', ('enables',)), ('NR0B1', ('enables',)), ('ZNFX1', ('enables',)), ('APOBEC3D', ('enables',)), ('PKN2', ('enables',)), ('RBM5', ('enables',)), ('NKRF', ('enables',)), ('TNS1', ('enables',)), ('MRPL32', ('enables',)), ('RPL10', ('enables',)), ('SSB', ('enables',)), ('PUM3', ('enables',)), ('H4C14', ('enables',)), ('FAM98A', ('enables',)), ('HDGF', ('enables',)), ('MRPS14', ('enables',)), ('CNOT6', ('enables',)), ('SRSF10', ('enables',)), ('WDR75', ('enables',)), ('LSM2', ('contributes_to',)), ('MYH9', ('enables',)), ('MTREX', ('enables',)), ('RPL18A', ('enables',)), ('DDX55', ('enables',)), ('PPP1R10', ('enables',)), ('SHFL', ('enables',)), ('BOP1', ('enables',)), ('PUSL1', ('enables',)), ('ASCC1', ('enables',)), ('MDH2', ('enables',)), ('RPL11', ('enables',)), ('RPP30', ('enables',)), ('SNRNP200', ('enables',)), ('GSPT2', ('enables',)), ('RAMACL', ('enables',)), ('GPBP1L1', ('enables',)), ('PATL2', ('enables',)), ('BRCA1', ('enables',)), ('PDCD4', ('enables',)), ('TENT5A', ('enables',)), ('CFAP65', ('enables',)), ('RNPS1', ('enables',)), ('KHDC1L', ('enables',)), ('NOP9', ('enables',)), ('C1orf35', ('enables',)), ('EIF3E', ('enables',)), ('UTP20', ('enables',)), ('SLC3A2', ('enables',)), ('TNRC6C', ('enables',)), ('ERH', ('enables',)), ('ZRANB2', ('enables',)), ('CAPRIN2', ('enables',)), ('ZNF326', ('enables',)), ('NOA1', ('enables',)), ('ZNF768', ('enables',)), ('RPP25', ('enables',)), ('MRPL11', ('enables',)), ('RPS16', ('enables',)), ('CCDC47', ('enables',)), ('EIF2S1', ('enables',)), ('DDX3Y', ('enables',)), ('NXF5', ('enables',)), ('MCTS2', ('enables',)), ('TRIR', ('enables',)), ('GNL3L', ('enables',)), ('PSMC1', ('enables',)), ('RPS10', ('enables',)), ('MYO18A', ('enables',)), ('CAPRIN1', ('enables',)), ('ISY1', ('enables',)), ('ERI3', ('enables',)), ('FNDC3A', ('enables',)), ('ZCCHC24', ('enables',)), ('H4C3', ('enables',)), ('SMNDC1', ('enables',)), ('AATF', ('enables',)), ('SMARCA4', ('enables',)), ('CCDC59', ('enables',)), ('RBMXL1', ('enables',)), ('ANXA11', ('enables',)), ('ERVK-9', ('enables',)), ('DDX56', ('enables',)), ('PABPC1L2A', ('enables',)), ('ALDH18A1', ('enables',)), ('DDX59', ('enables',)), ('THRAP3', ('enables',)), ('RPS26', ('enables',)), ('EXOSC5', ('enables',)), ('PDIA3', ('enables',)), ('LRRC59', ('enables',)), ('TIAL1', ('enables',)), ('ACO1', ('enables',)), ('SYNJ2', ('enables',)), ('TARDBP', ('enables',)), ('RBM20', ('enables',)), ('SART3', ('enables',)), ('STIP1', ('enables',)), ('RPL26L1', ('enables',)), ('ERAL1', ('enables',)), ('EZR', ('enables',)), ('CDK13', ('enables',)), ('RPL21', ('enables',)), ('MTRES1', ('enables',)), ('RO60', ('enables',)), ('NSUN7', ('enables',)), ('PDIA4', ('enables',)), ('ADARB2', ('enables',)), ('YBX3', ('enables',)), ('NOP10', ('enables',)), ('NOP16', ('enables',)), ('TEP1', ('enables',)), ('ARF1', ('enables',)), ('GRSF1', ('enables',)), ('FARSB', ('enables',)), ('PRKRA', ('enables',)), ('CACTIN', ('enables',)), ('WDR3', ('enables',)), ('GTPBP1', ('enables',)), ('CCDC86', ('enables',)), ('WDR33', ('enables',)), ('EXOSC10', ('enables',)), ('RTRAF', (' ...
# GO:0046872 {('ZNF566', ('enables',)), ('RFPL1', ('enables',)), ('NHLRC1', ('enables',)), ('CSK', ('enables',)), ('PHF3', ('enables',)), ('ZIC5', ('enables',)), ('ZNF823', ('enables',)), ('IMPDH1', ('enables',)), ('CYB5D1', ('enables',)), ('MFNG', ('enables',)), ('ZNF516', ('enables',)), ('ZNF723', ('enables',)), ('CDKAL1', ('enables',)), ('ZNF428', ('enables',)), ('RNF19A', ('enables',)), ('ZNF557', ('enables',)), ('GNE', ('enables',)), ('ZNF708', ('enables',)), ('FGA', ('enables',)), ('TKTL2', ('enables',)), ('POSTN', ('enables',)), ('SALL2', ('enables',)), ('ZNF677', ('enables',)), ('OSR1', ('enables',)), ('ZNF689', ('enables',)), ('ZSCAN5DP', ('enables',)), ('HIC2', ('enables',)), ('ZNF609', ('enables',)), ('RNF168', ('enables',)), ('ING5', ('enables',)), ('ZNF287', ('enables',)), ('SLC6A4', ('enables',)), ('PMPCA', ('enables',)), ('ZNF280D', ('enables',)), ('COPS5', ('enables',)), ('ADAP1', ('enables',)), ('KCND2', ('enables',)), ('DGKZ', ('enables',)), ('ZNF879', ('enables',)), ('CIT', ('enables',)), ('OVOL2', ('enables',)), ('ZNF273', ('enables',)), ('PDSS1', ('enables',)), ('DTX3', ('enables',)), ('SMAP1', ('enables',)), ('KDM4E', ('enables',)), ('ZNF547', ('enables',)), ('ANTXR1', ('enables',)), ('SMYD3', ('enables',)), ('GNA14', ('enables',)), ('ZFPM1', ('enables',)), ('GFI1', ('enables',)), ('ZNF700', ('enables',)), ('MKNK2', ('enables',)), ('ZNF680', ('enables',)), ('JMJD7', ('enables',)), ('MAP3K13', ('enables',)), ('AGMAT', ('enables',)), ('ZNF354A', ('enables',)), ('CACNA2D4', ('enables',)), ('MAB21L1', ('enables',)), ('PRDM1', ('enables',)), ('CSRP3', ('enables',)), ('CSH1', ('enables',)), ('ZNF281', ('enables',)), ('RBM5', ('enables',)), ('ALKBH7', ('enables',)), ('TNS1', ('enables',)), ('MOK', ('enables',)), ('SMYD4', ('enables',)), ('ZBTB34', ('enables',)), ('GET3', ('enables',)), ('THAP2', ('enables',)), ('ZNF484', ('enables',)), ('UQCRFS1P1', ('enables',)), ('ZBTB11', ('enables',)), ('UBOX5', ('enables',)), ('ARID2', ('enables',)), ('ZNF774', ('enables',)), ('NPAS2', ('enables',)), ('PPP6C', ('enables',)), ('ARMT1', ('enables',)), ('CNOT6', ('enables',)), ('ZNF266', ('enables',)), ('MOB4', ('enables',)), ('MYLIP', ('enables',)), ('ZNF711', ('enables',)), ('PXDNL', ('enables',)), ('OVCH1', ('enables',)), ('CBLL2', ('enables',)), ('ZNF85', ('enables',)), ('PPP1R10', ('enables',)), ('SLC38A9', ('enables',)), ('MT-CO1', ('enables',)), ('MCCC1', ('enables',)), ('DMRT1', ('enables',)), ('INTS12', ('enables',)), ('ZNF587B', ('enables',)), ('TTLL6', ('enables',)), ('THAP9', ('enables',)), ('ZNF131', ('enables',)), ('RPAIN', ('enables',)), ('ZNF839', ('enables',)), ('AGAP2', ('enables',)), ('NSD2', ('enables',)), ('HBM', ('enables',)), ('ZEB2', ('enables',)), ('CDC7', ('enables',)), ('ZNF564', ('enables',)), ('RNF181', ('enables',)), ('TOPORS', ('enables',)), ('NRP2', ('enables',)), ('POLR3B', ('enables',)), ('GDPD4', ('enables',)), ('TENT2', ('enables',)), ('HMOX2', ('enables',)), ('ZNF469', ('enables',)), ('ITGA5', ('enables',)), ('ATF7', ('enables',)), ('TRERF1', ('enables',)), ('AGAP1', ('enables',)), ('GALNT15', ('enables',)), ('NUDT13', ('enables',)), ('MPTX1', ('enables',)), ('ZMYND12', ('enables',)), ('LMX1A', ('enables',)), ('ZNF786', ('enables',)), ('SLC40A1', ('enables',)), ('PTGES3L-AARSD1', ('enables',)), ('OGDH', ('enables',)), ('ZBTB42', ('enables',)), ('DGKE', ('enables',)), ('ZNF330', ('enables',)), ('RSPRY1', ('enables',)), ('CNOT6L', ('enables',)), ('ZNF274', ('enables',)), ('GZF1', ('enables',)), ('ZRANB2', ('enables',)), ('CAPRIN2', ('enables',)), ('GNA11', ('enables',)), ('ZNF326', ('enables',)), ('PPM1F', ('enables',)), ('ITGAX', ('enables',)), ('ZNF841', ('enables',)), ('HDAC5', ('enables',)), ('RNF223', ('enables',)), ('ZNF284', ('enables',)), ('ZNF226', ('enables',)), ('HBB', ('enables',)), ('TRPM6', ('enables',)), ('ZNF697', ('enables',)), ('ZNF768', ('enables',)), ('TKTL1', ('enables',)), ('EXD3', ('enables',)), ('CACNA2D3', ('enables',)), ('FREM1', ('enables',)), ('TAX1BP1', ('enables',) ...
# GO:0005829 {('ETAA1', ('located_in',)), ('CAMKK1', ('located_in',)), ('RNF7', ('located_in',)), ('AP4B1', ('located_in',)), ('KLC1', ('located_in',)), ('NUP88', ('located_in',)), ('RASSF2', ('located_in',)), ('TPPP', ('located_in',)), ('SNAI1', ('located_in',)), ('RPL37', ('located_in',)), ('CCNE2', ('located_in',)), ('PLAAT5', ('located_in',)), ('RGS10', ('located_in',)), ('LGALS9C', ('is_active_in',)), ('DCP1B', ('located_in',)), ('ATG101', ('located_in',)), ('ZNF746', ('located_in',)), ('RGL1', ('located_in',)), ('USP42', ('is_active_in',)), ('HMBS', ('located_in',)), ('TCF7L1', ('located_in',)), ('TXNL4B', ('located_in',)), ('PCBP2', ('located_in',)), ('UBE2L6', ('located_in',)), ('CYGB', ('located_in',)), ('ARHGAP5', ('is_active_in',)), ('PMM2', ('located_in',)), ('RINT1', ('located_in',)), ('BIRC5', ('located_in',)), ('SYNCRIP', ('located_in',)), ('USP9X', ('located_in',)), ('PYCR3', ('located_in',)), ('KBTBD13', ('located_in',)), ('SGTA', ('located_in',)), ('TJP2', ('located_in',)), ('ARHGAP18', ('located_in',)), ('PRKACB', ('is_active_in',)), ('POLR3D', ('located_in',)), ('IRF8', ('located_in',)), ('VAC14', ('located_in',)), ('RPL27A', ('located_in',)), ('PIK3C2B', ('located_in',)), ('CTPS2', ('located_in',)), ('NNMT', ('located_in',)), ('CARNS1', ('located_in',)), ('CD1B', ('located_in',)), ('STK4', ('located_in',)), ('MOCS2', ('is_active_in',)), ('AMPD3', ('is_active_in',)), ('FANCG', ('located_in',)), ('UBE3A', ('is_active_in',)), ('THUMPD3', ('located_in',)), ('VAV2', ('located_in',)), ('NSMAF', ('located_in',)), ('MSR1', ('located_in',)), ('DENND2D', ('is_active_in',)), ('PNPLA4', ('located_in',)), ('NSL1', ('located_in',)), ('WIPI1', ('is_active_in',)), ('PTGIR', ('located_in',)), ('BAG4', ('is_active_in',)), ('CCT4', ('located_in',)), ('EEF1D', ('is_active_in',)), ('ARRB1', ('located_in',)), ('VPS41', ('located_in',)), ('STK40', ('located_in',)), ('NTN1', ('located_in',)), ('KRT73', ('located_in',)), ('PADI4', ('located_in',)), ('HDAC4', ('located_in',)), ('SNX2', ('located_in',)), ('ACOT11', ('located_in',)), ('SMAD7', ('located_in',)), ('LSM1', ('located_in',)), ('OSBPL1A', ('located_in',)), ('MYLK3', ('located_in',)), ('NT5E', ('located_in',)), ('TRAF3', ('located_in',)), ('RPL36AL', ('located_in',)), ('ZFYVE16', ('located_in',)), ('NUDCD1', ('located_in',)), ('LCP1', ('located_in',)), ('NUP153', ('located_in',)), ('SCLT1', ('located_in',)), ('XYLB', ('located_in',)), ('RBBP4', ('located_in',)), ('ABCE1', ('located_in',)), ('RAB3GAP1', ('located_in',)), ('GCC1', ('located_in',)), ('AKR1B10', ('located_in',)), ('SEPSECS', ('located_in',)), ('CDCA3', ('located_in',)), ('SNRPG', ('located_in',)), ('USP9Y', ('is_active_in',)), ('LARP4B', ('located_in',)), ('FMR1', ('located_in',)), ('ARF6', ('located_in',)), ('FBXO31', ('located_in',)), ('HSFY1', ('located_in',)), ('PLEKHG5', ('located_in',)), ('ITGB1BP1', ('located_in',)), ('APBA1', ('located_in',)), ('MYH14', ('located_in',)), ('USP17L6P', ('is_active_in',)), ('HSF2BP', ('located_in',)), ('WASH4P', ('located_in',)), ('TSPO', ('located_in',)), ('CA7', ('located_in',)), ('MAPK9', ('located_in',)), ('GOLPH3L', ('located_in',)), ('RGS6', ('located_in',)), ('CHMP7', ('located_in',)), ('RBM38', ('is_active_in',)), ('ATP7A', ('located_in',)), ('PBOV1', ('located_in',)), ('GHR', ('located_in',)), ('GSTT2', ('located_in',)), ('KRT78', ('located_in',)), ('PRF1', ('located_in',)), ('SAMSN1', ('located_in',)), ('PTPN18', ('located_in',)), ('NEURL2', ('located_in',)), ('PSME1', ('located_in',)), ('ATM', ('located_in',)), ('NSF', ('located_in',)), ('FAF1', ('located_in',)), ('OAS2', ('located_in',)), ('SPG21', ('located_in',)), ('EIF2B5', ('located_in',)), ('GMEB2', ('located_in',)), ('MYO1F', ('located_in',)), ('TUBD1', ('located_in',)), ('TPI1', ('is_active_in',)), ('SPIRE2', ('located_in',)), ('GLUD2', ('NOT', 'located_in')), ('EIF2D', ('located_in',)), ('USP13', ('is_active_in',)), ('USP41', ('is_active_in',)), ('HAUS3', ('located_in',)), ('BYSL', ('located_in',)), ('RPL ...
# GO:0002250 {('TRGV3', ('involved_in',)), ('IGKV4-1', ('involved_in',)), ('IGKV2-28', ('involved_in',)), ('IGLV5-39', ('involved_in',)), ('OTUB1', ('involved_in',)), ('TRAV10', ('involved_in',)), ('TRAV8-1', ('involved_in',)), ('HLA-DQA1', ('involved_in',)), ('KLRC1', ('involved_in',)), ('TAP1', ('involved_in',)), ('TRBV17', ('involved_in',)), ('CLEC4C', ('involved_in',)), ('CD1A', ('involved_in',)), ('ANXA1', ('involved_in',)), ('IGKV3-20', ('involved_in',)), ('IFNA16', ('involved_in',)), ('IGKV6D-41', ('involved_in',)), ('TRBJ1-3', ('involved_in',)), ('IGKV1D-43', ('involved_in',)), ('TRGC2', ('involved_in',)), ('TRAV26-1', ('involved_in',)), ('LAT', ('involved_in',)), ('CTSL', ('involved_in',)), ('CD3G', ('involved_in',)), ('IGHG3', ('involved_in',)), ('TEC', ('involved_in',)), ('IGKV3D-15', ('involved_in',)), ('TRAV24', ('involved_in',)), ('TRAV8-4', ('involved_in',)), ('LAG3', ('involved_in',)), ('SYK', ('involved_in',)), ('TRBV25-1', ('involved_in',)), ('HLA-B', ('involved_in',)), ('TRBV30', ('involved_in',)), ('IGKV1D-13', ('involved_in',)), ('ALCAM', ('involved_in',)), ('IGLV4-60', ('involved_in',)), ('CLEC4M', ('involved_in',)), ('IGHA1', ('involved_in',)), ('IGLV9-49', ('involved_in',)), ('GPR183', ('involved_in',)), ('CD1B', ('involved_in',)), ('IGHA2', ('involved_in',)), ('TRBV6-4', ('involved_in',)), ('TRBJ2-1', ('involved_in',)), ('TRBC2', ('involved_in',)), ('TRAV17', ('involved_in',)), ('IGLV3-1', ('involved_in',)), ('SIT1', ('involved_in',)), ('IFNW1', ('involved_in',)), ('PRR7', ('involved_in',)), ('TRAV8-3', ('involved_in',)), ('HLA-DRB3', ('involved_in',)), ('JAM3', ('involved_in',)), ('PDCD1LG2', ('involved_in',)), ('IGKV1D-17', ('involved_in',)), ('IGLV3-22', ('involved_in',)), ('IGKV2D-30', ('involved_in',)), ('TRBV23-1', ('involved_in',)), ('IGKV1-33', ('involved_in',)), ('HLA-DPA1', ('involved_in',)), ('LYN', ('involved_in',)), ('LILRA6', ('involved_in',)), ('IGKV2-30', ('involved_in',)), ('IGLV1-36', ('involved_in',)), ('PIK3CD', ('involved_in',)), ('TRBJ2-2', ('involved_in',)), ('TRAV34', ('involved_in',)), ('TRAV38-1', ('involved_in',)), ('IGHV3-38-3', ('involved_in',)), ('KLRC2', ('involved_in',)), ('LILRB4', ('involved_in',)), ('IGLJ1', ('involved_in',)), ('CD3E', ('involved_in',)), ('IGKJ1', ('involved_in',)), ('BTN3A1', ('involved_in',)), ('TREM1', ('involved_in',)), ('TRBV6-7', ('involved_in',)), ('DCLRE1C', ('involved_in',)), ('IGKV1D-12', ('involved_in',)), ('TNFRSF14', ('involved_in',)), ('IGHG1', ('involved_in',)), ('ERAP2', ('involved_in',)), ('CD1E', ('involved_in',)), ('VTCN1', ('involved_in',)), ('HLA-DOA', ('involved_in',)), ('IGLV2-8', ('involved_in',)), ('IGKV1-12', ('involved_in',)), ('IL2', ('involved_in',)), ('TRBJ2-5', ('involved_in',)), ('PRKD2', ('involved_in',)), ('CTNNBL1', ('involved_in',)), ('CD4', ('involved_in',)), ('IGLC6', ('involved_in',)), ('TRBV10-3', ('involved_in',)), ('IL17A', ('involved_in',)), ('FCRL4', ('involved_in',)), ('CD6', ('involved_in',)), ('CD8B2', ('involved_in',)), ('LILRB5', ('involved_in',)), ('TSC1', ('involved_in',)), ('HLA-DMB', ('involved_in',)), ('TRBJ1-2', ('involved_in',)), ('IGKV1-16', ('involved_in',)), ('TRBJ2-3', ('involved_in',)), ('TRAV9-1', ('involved_in',)), ('TRBV14', ('involved_in',)), ('IGKV5-2', ('involved_in',)), ('CD274', ('involved_in',)), ('IGHD', ('involved_in',)), ('TRAV7', ('involved_in',)), ('TRGV9', ('involved_in',)), ('IGLV4-3', ('involved_in',)), ('TRGV5', ('involved_in',)), ('TRDV1', ('involved_in',)), ('IGLV3-21', ('involved_in',)), ('IGLV1-47', ('involved_in',)), ('BMX', ('involved_in',)), ('IGLV7-46', ('involved_in',)), ('IGKV1-5', ('involved_in',)), ('ADGRE1', ('involved_in',)), ('TRBJ1-5', ('involved_in',)), ('IGKV3D-11', ('involved_in',)), ('TRBV10-2', ('involved_in',)), ('SH2D1A', ('involved_in',)), ('FCGR1BP', ('involved_in',)), ('HLA-DQB1', ('involved_in',)), ('IGLV3-32', ('involved_in',)), ('HLA-DRB4', ('involved_in',)), ('TRBV13', ('involved_in',)), ('IGKV1D-8', ('involved_in',)), ('TRBV11-2', ('involved_in' ...
# GO:0005886 {('NTN4', ('located_in',)), ('ANK2', ('is_active_in',)), ('OR2W5P', ('located_in',)), ('GPR146', ('located_in',)), ('ALKAL1', ('located_in',)), ('RHO', ('is_active_in',)), ('RASSF2', ('located_in',)), ('ICAM1', ('located_in',)), ('SCNN1B', ('located_in',)), ('RGS10', ('located_in',)), ('LANCL3', ('is_active_in',)), ('TMEM119', ('located_in',)), ('MS4A1', ('is_active_in',)), ('CLDN5', ('located_in',)), ('CD69', ('located_in',)), ('ATP11C', ('located_in',)), ('NRN1L', ('located_in',)), ('GUCA1B', ('located_in',)), ('OR1D2', ('is_active_in',)), ('ATP10B', ('is_active_in',)), ('TMEM59', ('located_in',)), ('SKAP2', ('is_active_in',)), ('RERG', ('is_active_in',)), ('GPR26', ('located_in',)), ('GRM8', ('located_in',)), ('FCRL4', ('is_active_in',)), ('GFRA4', ('located_in',)), ('IGLV3-9', ('located_in',)), ('ANO9', ('located_in',)), ('OR2L13', ('located_in',)), ('SLC2A1', ('is_active_in',)), ('FCHO1', ('is_active_in',)), ('SPTBN1', ('is_active_in',)), ('KLRG1', ('located_in',)), ('TJP2', ('located_in',)), ('FAM171A1', ('is_active_in',)), ('KCNH6', ('located_in',)), ('ARHGAP18', ('located_in',)), ('KCNK18', ('located_in',)), ('PIK3C2B', ('located_in',)), ('SLCO5A1', ('is_active_in',)), ('SERINC1', ('located_in',)), ('FZD5', ('located_in',)), ('MYADM', ('is_active_in',)), ('CD1B', ('located_in',)), ('FANCG', ('located_in',)), ('UNC93A', ('located_in',)), ('CATSPERD', ('located_in',)), ('VAV2', ('located_in',)), ('TAS2R10', ('located_in',)), ('ALG10B', ('located_in',)), ('MSR1', ('located_in',)), ('WNT3', ('located_in',)), ('SLC52A3', ('located_in',)), ('C4B_2', ('located_in',)), ('OR5L2', ('located_in',)), ('PTGIR', ('located_in',)), ('OR10AC1', ('located_in',)), ('TIE1', ('is_active_in',)), ('ASAH2', ('located_in',)), ('GPR153', ('located_in',)), ('TRBV13', ('is_active_in',)), ('CADM3', ('located_in',)), ('IGF1R', ('is_active_in',)), ('PCDHB13', ('is_active_in',)), ('CLDN19', ('is_active_in',)), ('SMAD7', ('located_in',)), ('CLDN6', ('is_active_in',)), ('GNG7', ('located_in',)), ('KLRF1', ('is_active_in',)), ('NT5E', ('located_in',)), ('RPL36AL', ('located_in',)), ('TMEM63B', ('located_in',)), ('NTRK2', ('is_active_in',)), ('LCP1', ('located_in',)), ('GNG10', ('located_in',)), ('GABRA3', ('is_active_in',)), ('BLTP2', ('located_in',)), ('ARF6', ('located_in',)), ('NOTCH2', ('located_in',)), ('OR5J2', ('located_in',)), ('CLCA1', ('is_active_in',)), ('CLDN17', ('is_active_in',)), ('ITGB1BP1', ('located_in',)), ('SNAP47', ('is_active_in',)), ('CD8B2', ('located_in',)), ('OR6K2', ('located_in',)), ('MAPK9', ('located_in',)), ('PCYOX1', ('located_in',)), ('RGS6', ('located_in',)), ('CHMP7', ('located_in',)), ('ATP7A', ('located_in',)), ('C17orf99', ('is_active_in',)), ('SLC7A2', ('is_active_in',)), ('CASR', ('located_in',)), ('GHR', ('located_in',)), ('KCNJ3', ('is_active_in',)), ('NCR3LG1', ('located_in',)), ('LPAR4', ('located_in',)), ('PRF1', ('located_in',)), ('OR7D4', ('located_in',)), ('VXN', ('located_in',)), ('MYPN', ('is_active_in',)), ('TNFRSF21', ('is_active_in',)), ('CD177', ('is_active_in',)), ('IGKV3D-11', ('located_in',)), ('RFTN1', ('located_in',)), ('PCDHGA3', ('is_active_in',)), ('EMP1', ('located_in',)), ('TSPAN14', ('is_active_in',)), ('LYPD2', ('located_in',)), ('TSPAN18', ('is_active_in',)), ('CD53', ('located_in',)), ('NSF', ('located_in',)), ('WNT7B', ('located_in',)), ('AOC3', ('located_in',)), ('ITSN2', ('is_active_in',)), ('LILRB3', ('located_in',)), ('SLC8A2', ('is_active_in',)), ('DAGLB', ('located_in',)), ('APOBR', ('located_in',)), ('GLP1R', ('is_active_in',)), ('CLDN3', ('is_active_in',)), ('PLXNA4', ('is_active_in',)), ('OR2A2', ('located_in',)), ('ATP6V0A2', ('is_active_in',)), ('TRBV5-6', ('is_active_in',)), ('GRIK3', ('is_active_in',)), ('OR5K1', ('located_in',)), ('MS4A18', ('is_active_in',)), ('SLC5A3', ('is_active_in',)), ('PSTPIP2', ('is_active_in',)), ('CD59', ('is_active_in',)), ('RAPH1', ('is_active_in',)), ('IGKV2D-24', ('located_in',)), ('CCR7', ('located_in',)), ('IL1R2', ('located_in' ...

# %%
print(g)
# Out:
# DiGraph with 92145 nodes and 89524 edges
