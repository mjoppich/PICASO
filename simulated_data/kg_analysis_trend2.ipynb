# %%
# %load_ext autoreload

import os, sys
import networkx as nx

sys.path.insert(0, "../")
sys.path.insert(0, "/home/j/joppich/.local/lib/python3.11/site-packages/")
print(sys.path)

# %autoreload 2
from PICASO.kgraph import *
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import leidenalg as la

from collections import defaultdict, Counter

import random
random.seed(42)

import pickle
# Out:
# ['/home/j/joppich/.local/lib/python3.11/site-packages/', '../', '', '/opt/jhub/lib/python3.11/site-packages', '/opt/jhub/lib64/python3.11/site-packages', '/mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python311.zip', '/mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11', '/mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/lib-dynload', '/home/users/joppich/.local/lib/python3.11/site-packages', '/mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/site-packages']

# %%
simulatedGenes = pd.read_csv("./simulated_changes_detail.tsv", sep="\t")
simulatedGenes
# Out:
#      wildtype  stage1  stage2  stage3  \
# 0           1       4       1       1
# 1           1       4       1       1
# 2           1       4       1       1
# 3           1       4       1       1
# 4           1       4       1       1
# ..        ...     ...     ...     ...
# 414         1       2       2       8
# 415         1       2       2       8
# 416         1       2       2       8
# 417         1       2       2       8
# 418         1       2       2       8
#
#                                       geneset   trend element_type   gene
# 0                 AMIT_EGF_RESPONSE_40_MCF10A  trend1         gene    ADM
# 1                 AMIT_EGF_RESPONSE_40_MCF10A  trend1         gene   BUB1
# 2                 AMIT_EGF_RESPONSE_40_MCF10A  trend1         gene  DUSP5
# 3                 AMIT_EGF_RESPONSE_40_MCF10A  trend1         gene   EGR1
# 4                 AMIT_EGF_RESPONSE_40_MCF10A  trend1         gene   EGR3
# ..                                        ...     ...          ...    ...
# 414  REACTOME_PI5P_REGULATES_TP53_ACETYLATION  trend4         gene   TP53
# 415  REACTOME_PI5P_REGULATES_TP53_ACETYLATION  trend4           tf   E2F1
# 416  REACTOME_PI5P_REGULATES_TP53_ACETYLATION  trend4           tf    SP1
# 417  REACTOME_PI5P_REGULATES_TP53_ACETYLATION  trend4           tf  STAT1
# 418  REACTOME_PI5P_REGULATES_TP53_ACETYLATION  trend4           tf   EGR1
#
# [419 rows x 8 columns]

# %%
set(simulatedGenes["geneset"])
# Out:
# {'AMIT_EGF_RESPONSE_40_MCF10A',
#  'BIOCARTA_ERBB3_PATHWAY',
#  'BIOCARTA_FEEDER_PATHWAY',
#  'BIOCARTA_IL22BP_PATHWAY',
#  'BIOCARTA_RNAPOL3_PATHWAY',
#  'BIOCARTA_SARS_PATHWAY',
#  'BIOCARTA_SET_PATHWAY',
#  'CAFFAREL_RESPONSE_TO_THC_8HR_5_UP',
#  'DACOSTA_LOW_DOSE_UV_RESPONSE_VIA_ERCC3_XPCS_DN',
#  'DASU_IL6_SIGNALING_DN',
#  'FARDIN_HYPOXIA_9',
#  'FINETTI_BREAST_CANCER_KINOME_RED',
#  'GHO_ATF5_TARGETS_UP',
#  'GREENBAUM_E2A_TARGETS_DN',
#  'HEDENFALK_BREAST_CANCER_BRACX_UP',
#  'IIZUKA_LIVER_CANCER_EARLY_RECURRENCE',
#  'IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN',
#  'IM_SREBF1A_TARGETS',
#  'KEGG_MEDICUS_REFERENCE_AUTOPHAGY_VESICLE_NUCLEATION_ELONGATION_MATURATION_E3_UBIQUITIN_LIGASE_MALIN',
#  'KEGG_MEDICUS_REFERENCE_COPII_VESICLE_FORMATION',
#  'KEGG_MEDICUS_REFERENCE_II_BLOOD_GROUP_ANTIGEN_BIOSYNTHESIS',
#  'KEGG_MEDICUS_REFERENCE_REGULATION_OF_GF_RTK_RAS_ERK_SIGNALING_MRAS_SHOC2_PP1_HOLOPHOSPHATASE',
#  'KIM_GERMINAL_CENTER_T_HELPER_DN',
#  'MCBRYAN_TERMINAL_END_BUD_DN',
#  'MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN',
#  'MUNSHI_MULTIPLE_MYELOMA_DN',
#  'PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN',
#  'RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN',
#  'REACTOME_APOBEC3G_MEDIATED_RESISTANCE_TO_HIV_1_INFECTION',
#  'REACTOME_ATTACHMENT_OF_GPI_ANCHOR_TO_UPAR',
#  'REACTOME_COBALAMIN_CBL_METABOLISM',
#  'REACTOME_GLUTAMATE_AND_GLUTAMINE_METABOLISM',
#  'REACTOME_GLYCOSPHINGOLIPID_BIOSYNTHESIS',
#  'REACTOME_MITOCHONDRIAL_RNA_DEGRADATION',
#  'REACTOME_PHENYLALANINE_AND_TYROSINE_METABOLISM',
#  'REACTOME_PHENYLALANINE_METABOLISM',
#  'REACTOME_PI5P_REGULATES_TP53_ACETYLATION',
#  'STONER_ESOPHAGEAL_CARCINOGENESIS_DN',
#  'TSUDA_ALVEOLAR_SOFT_PART_SARCOMA',
#  'ZIRN_TRETINOIN_RESPONSE_DN'}

# %%
simulatedNetwork = pd.read_csv("./simulated_network.tsv", sep="\t", usecols=["TF", "gene"])
simulatedNetwork
# Out:
#          TF   gene
# 0     CEBPB    ADM
# 1      TP53   EGR1
# 2    NFATC2   EGR3
# 3       FOS    FOS
# 4       JUN    FOS
# ..      ...    ...
# 119     SP1   UGCG
# 120    EGR1  EP300
# 121    E2F1   PIN1
# 122   HMGA1   TP53
# 123    TP53   TP53
#
# [124 rows x 2 columns]

# %%
trend2gene = defaultdict(set)
trend2pathways = defaultdict(set)
pathways2genes = defaultdict(set)
gene2type = defaultdict(set)
gene2trends = defaultdict(set)

for ri, row in simulatedGenes.iterrows():

    trend2gene[row["trend"]].add(row["gene"])
    trend2pathways[row["trend"]].add(row["geneset"])
    pathways2genes[row["geneset"]].add(row["gene"])

    gene2type[row["gene"]].add(row["element_type"])
    gene2trends[row["gene"]].add(row["trend"])

# %%
for trend in trend2pathways:
    print(trend, len(trend2pathways[trend]), len(trend2gene[trend]))
# Out:
# trend1 10 141
# trend2 10 100
# trend3 10 89
# trend4 10 79

# %%
stageSort = {
    "wildtype": 0,
    "stage1": 1,
    "stage2": 2,
    "stage3": 3
}

basedir = "comms"

# %%
kg = KGraph()
kg.load_kgraph("../data/initial_base_graph.out")

# %%
kg
# Out:
# KGraph KGraph with 111032 nodes and 1617389 edges

# %%
kg.get_edge_between_type()
# Out:
# Counter({('gene', 'geneset'): 841157,
#          ('gene', 'gene'): 344408,
#          ('TF;gene', 'gene'): 95771,
#          ('geneset', 'geneset'): 74634,
#          ('TF;gene', 'geneset'): 74544,
#          ('gene', 'disease'): 43297,
#          ('gene', 'geneset;subcellular_location'): 40554,
#          ('disease', 'drug'): 35017,
#          ('gene', 'TF;gene'): 19994,
#          ('TF;gene', 'TF;gene'): 16120,
#          ('gene', 'drug'): 7899,
#          ('miRNA;ncRNA', 'gene'): 7848,
#          ('TF;gene', 'disease'): 5105,
#          ('TF;gene', 'miRNA;ncRNA'): 2099,
#          ('TF;gene', 'geneset;subcellular_location'): 2043,
#          ('miRNA;ncRNA', 'TF;gene'): 1808,
#          ('gene', 'disease;geneset'): 1714,
#          ('geneset;subcellular_location', 'geneset;subcellular_location'): 721,
#          ('gene', 'miRNA;ncRNA'): 651,
#          ('geneset;subcellular_location', 'geneset'): 460,
#          ('gene;lncRNA;ncRNA', 'geneset'): 444,
#          ('TF;gene', 'drug'): 341,
#          ('geneset', 'disease;geneset'): 200,
#          ('TF;gene', 'disease;geneset'): 147,
#          ('gene;lncRNA;ncRNA', 'gene'): 120,
#          ('disease;geneset', 'geneset'): 95,
#          ('lncRNA;ncRNA', 'gene'): 49,
#          ('gene', 'gene;lncRNA;ncRNA'): 36,
#          ('disease;geneset', 'drug'): 34,
#          ('gene;lncRNA;ncRNA', 'TF;gene'): 33,
#          ('TF;gene', 'gene;lncRNA;ncRNA'): 20,
#          ('lncRNA;ncRNA', 'TF;gene'): 12,
#          ('gene;lncRNA;ncRNA', 'geneset;subcellular_location'): 6,
#          ('disease;geneset', 'disease;geneset'): 5,
#          ('lncRNA;ncRNA', 'lncRNA;ncRNA'): 2,
#          ('gene;lncRNA;ncRNA', 'disease'): 1})

# %%
containedEdges = 0
for ri, row in simulatedNetwork.iterrows():
    edgeContained = (row["TF"], row["gene"]) in kg.kg.edges
    if edgeContained:
        containedEdges += 1

    if not edgeContained:
        print(row["TF"], row["gene"], edgeContained)

print(containedEdges, ri+1, containedEdges/(ri+1))
# Out:
# FOS FOS False
# JUN JUN False
# TNFAIP3 JUN False
# RBMX JUND False
# ZFP36 VEGFA False
# ZFP36L1 VEGFA False
# RBMX JUNB False
# SMAD4 PDGFRA False
# APC SGK1 False
# PER1 BAX False
# IRF1 MAPK14 False
# SERTAD1 SET False
# TP53 TP53 False
# 111 124 0.8951612903225806

# %%
simNetwork = pd.read_csv("./simulated_network.tsv", sep="\t")
simNetwork.head()
# Out:
#        TF  gene
# 0   CEBPB   ADM
# 1    TP53  EGR1
# 2  NFATC2  EGR3
# 3     FOS   FOS
# 4     JUN   FOS

# %%
for ri, row in simNetwork.iterrows():
    et = (row["TF"], row["gene"])
    edge = et in kg.kg.edges
    edge_r = tuple(et[::-1]) in kg.kg.edges

    if not edge and not edge_r:
        print(et, edge, edge_r)
# Out:
# ('FOS', 'FOS') False False
# ('JUN', 'JUN') False False
# ('RBMX', 'JUND') False False
# ('ZFP36', 'VEGFA') False False
# ('ZFP36L1', 'VEGFA') False False
# ('RBMX', 'JUNB') False False
# ('SMAD4', 'PDGFRA') False False
# ('APC', 'SGK1') False False
# ('PER1', 'BAX') False False
# ('IRF1', 'MAPK14') False False
# ('SERTAD1', 'SET') False False
# ('TP53', 'TP53') False False

# %%
exprDF = pd.read_csv("./expression_simulated_mean_df.tsv", sep="\t")

# %%
exprDF.head()
# Out:
#     group       gene       min  percentile_25    median  percentile_75  \
# 0  stage1       A1BG  0.135103       0.299755  0.369649       0.448072
# 1  stage1   A1BG.AS1  0.138112       0.319603  0.387099       0.479105
# 2  stage1        A2M  0.119602       0.361211  0.468807       0.657032
# 3  stage1    A2M.AS1  0.133371       0.304632  0.382526       0.477938
# 4  stage1  A2ML1.AS1  0.119602       0.388011  0.509231       0.755049
#
#         max      mean  num        sd  group_cells  perc_expr
# 0  0.762750  0.381845   69  0.123641         5419   0.012733
# 1  1.044375  0.404958  308  0.144913         5419   0.056837
# 2  2.089658  0.528361  746  0.244020         5419   0.137664
# 3  0.992434  0.397057  321  0.133843         5419   0.059236
# 4  2.050669  0.600180  747  0.296454         5419   0.137848

# %%
exprDFs = {}

for group in sorted(exprDF.group.unique(), key=lambda x: stageSort.get(x, -1)):
    exprDFs[group] = exprDF[exprDF.group == group].copy()

print([x for x in exprDFs])
# Out:
# ['wildtype', 'stage1', 'stage2', 'stage3']

# %%
kg.get_node_types()
# Out:
# Counter({'geneset': 55163,
#          'gene': 41990,
#          'disease': 7781,
#          'drug': 3195,
#          'TF;gene': 1630,
#          'miRNA;ncRNA': 593,
#          'geneset;subcellular_location': 557,
#          'disease;geneset': 61,
#          'lncRNA;ncRNA': 36,
#          'gene;lncRNA;ncRNA': 26})

# %%
kg.get_edge_types()
# Out:
# Counter({'part_of': 748950,
#          'interacts': 434239,
#          'relevant_in': 205461,
#          'activates': 158390,
#          'affected_by': 35051,
#          'represses': 27058,
#          'target_of': 8240})

# %%
exprKGs = {}

gsa = GenesetAnnotator()
mNS = MeanNetworkScorer()

for group in exprDFs:
    
    print(group)
    
    gKG = KGraph()
    
    gKG.load_kgraph("../data/initial_base_graph.out")

    gKG.add_gene_expression(exprDFs[group])
    mNS.score_nodes_from_properties(gKG)

    mNS.score(gKG)

    gsa.annotate_genesets(gKG, settype="disease", targettype="gene")
    gsa.annotate_genesets(gKG, settype="geneset", targettype="gene")
    gsa.annotate_genesets(gKG, settype="ncRNA", targettype="gene")
        
    exprKGs[group] = gKG
# Out:
# wildtype
# Measured Genes 15099
# Found Genes 14018
# /mnt/raidbio/extproj/projekte/regulatory_networks/simulated_data/../mikg/kgraph.py:1698: RuntimeWarning: invalid value encountered in scalar divide
#   edge_zscore = (edge_score-etype2mean[etype])/etype2std[etype]
# Processed 7884 of 43646 target nodes for settype=disease and targettype=gene
# Processed 42878 of 43646 target nodes for settype=geneset and targettype=gene
# Processed 3390 of 43646 target nodes for settype=ncRNA and targettype=gene
# stage1
# Measured Genes 15099
# Found Genes 14019
# Processed 7884 of 43646 target nodes for settype=disease and targettype=gene
# Processed 42878 of 43646 target nodes for settype=geneset and targettype=gene
# Processed 3390 of 43646 target nodes for settype=ncRNA and targettype=gene
# stage2
# Measured Genes 15096
# Found Genes 14015
# Processed 7884 of 43646 target nodes for settype=disease and targettype=gene
# Processed 42878 of 43646 target nodes for settype=geneset and targettype=gene
# Processed 3390 of 43646 target nodes for settype=ncRNA and targettype=gene
# stage3
# Measured Genes 15094
# Found Genes 14014
# Processed 7884 of 43646 target nodes for settype=disease and targettype=gene
# Processed 42878 of 43646 target nodes for settype=geneset and targettype=gene
# Processed 3390 of 43646 target nodes for settype=ncRNA and targettype=gene

# %% [raw]
# $trend1
#         1-4-1-1
# $trend2
#         8-2-1-1
# $trend3
#         1-2-4-1
# $trend4
#         1-2-2-8

# %%
stage2trend = {
    "wildtype": "trend2",
    "stage1": "trend1",
    "stage2": "trend3",
    "stage3": "trend4"
}

# %%
DiffKG = DifferentialKG()

# %%
dkg = DiffKG.get_differential_graph(exprKGs["wildtype"], exprKGs["stage1"])
# Out:
# /mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/site-packages/scipy/stats/_stats_py.py:6556: RuntimeWarning: invalid value encountered in scalar divide
#   svar = ((n1 - 1) * v1 + (n2 - 1) * v2) / df
# /mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1113: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /mnt/extproj/projekte/bartelt/software/miniconda3/envs/regnetworks/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1113: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %%
trend2pathways
# Out:
# defaultdict(set,
#             {'trend1': {'AMIT_EGF_RESPONSE_40_MCF10A',
#               'CAFFAREL_RESPONSE_TO_THC_8HR_5_UP',
#               'DACOSTA_LOW_DOSE_UV_RESPONSE_VIA_ERCC3_XPCS_DN',
#               'DASU_IL6_SIGNALING_DN',
#               'FARDIN_HYPOXIA_9',
#               'FINETTI_BREAST_CANCER_KINOME_RED',
#               'GHO_ATF5_TARGETS_UP',
#               'GREENBAUM_E2A_TARGETS_DN',
#               'HEDENFALK_BREAST_CANCER_BRACX_UP',
#               'IIZUKA_LIVER_CANCER_EARLY_RECURRENCE'},
#              'trend2': {'IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN',
#               'IM_SREBF1A_TARGETS',
#               'KIM_GERMINAL_CENTER_T_HELPER_DN',
#               'MCBRYAN_TERMINAL_END_BUD_DN',
#               'MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN',
#               'MUNSHI_MULTIPLE_MYELOMA_DN',
#               'PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN',
#               'RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN',
#               'STONER_ESOPHAGEAL_CARCINOGENESIS_DN',
#               'TSUDA_ALVEOLAR_SOFT_PART_SARCOMA'},
#              'trend3': {'BIOCARTA_ERBB3_PATHWAY',
#               'BIOCARTA_FEEDER_PATHWAY',
#               'BIOCARTA_IL22BP_PATHWAY',
#               'BIOCARTA_RNAPOL3_PATHWAY',
#               'BIOCARTA_SARS_PATHWAY',
#               'BIOCARTA_SET_PATHWAY',
#               'KEGG_MEDICUS_REFERENCE_AUTOPHAGY_VESICLE_NUCLEATION_ELONGATION_MATURATION_E3_UBIQUITIN_LIGASE_MALIN',
#               'KEGG_MEDICUS_REFERENCE_COPII_VESICLE_FORMATION',
#               'KEGG_MEDICUS_REFERENCE_II_BLOOD_GROUP_ANTIGEN_BIOSYNTHESIS',
#               'ZIRN_TRETINOIN_RESPONSE_DN'},
#              'trend4': {'KEGG_MEDICUS_REFERENCE_REGULATION_OF_GF_RTK_RAS_ERK_SIGNALING_MRAS_SHOC2_PP1_HOLOPHOSPHATASE',
#               'REACTOME_APOBEC3G_MEDIATED_RESISTANCE_TO_HIV_1_INFECTION',
#               'REACTOME_ATTACHMENT_OF_GPI_ANCHOR_TO_UPAR',
#               'REACTOME_COBALAMIN_CBL_METABOLISM',
#               'REACTOME_GLUTAMATE_AND_GLUTAMINE_METABOLISM',
#               'REACTOME_GLYCOSPHINGOLIPID_BIOSYNTHESIS',
#               'REACTOME_MITOCHONDRIAL_RNA_DEGRADATION',
#               'REACTOME_PHENYLALANINE_AND_TYROSINE_METABOLISM',
#               'REACTOME_PHENYLALANINE_METABOLISM',
#               'REACTOME_PI5P_REGULATES_TP53_ACETYLATION'}})

# %%
dkg.kg.nodes["IM_SREBF1A_TARGETS"]
# Out:
# {'id': 'IM_SREBF1A_TARGETS',
#  'type': {'geneset'},
#  'name': 'IM_SREBF1A_TARGETS',
#  'score': 0.7587672411492866,
#  'source': 'kegg',
#  'fc': {'score': 1.2381757746711493, 'sig': 0.05355132513658523},
#  'fc_score': 1.2381757746711493}

# %%
fig, ax = plt.subplots(figsize=(8, 4))
for trend in trend2gene:
    dkg.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc_score"], nodes=trend2gene[trend], ax=ax, title=trend)
dkg.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc_score"], ax=ax, title="all genes")
plt.title("Cumulative Histogram of Gene Fold Changes")
# Out:
# Text(0.5, 1.0, 'Cumulative Histogram of Gene Fold Changes')

# %%
fig, ax = plt.subplots(figsize=(8, 4))
for trend in trend2gene:
    dkg.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc_score"], nodes=trend2pathways[trend], ax=ax, title=trend)
dkg.plot_node_attribute_histogram(node_type="geneset", attribute_accessor=lambda x: x["fc_score"], ax=ax, title="all pws")
plt.title("Cumulative Histogram of Pathway Fold Changes")
# Out:
# Text(0.5, 1.0, 'Cumulative Histogram of Pathway Fold Changes')

# %%
fig, ax = plt.subplots(figsize=(8, 4))
for trend in trend2gene:
    dkg.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc"]["sig"], nodes=trend2gene[trend], ax=ax, title=trend)
dkg.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc"]["sig"], ax=ax, title="all genes", node_type="gene")

# %%
def geneset_filter(n, kg):

    if kg.node_type_overlap(n, ["disease", "geneset"]):
        if len(kg._get_predecessors(n, ntype="gene")) < 5:
            return False

        if kg.kg.nodes[n]["fc"]["sig"] > 0.1:
            return False
   
    elif kg.node_type_overlap(n, ["gene"]):
        if kg.kg.nodes[n]["fc"]["sig"] > 0.9:
            return False

    else:
        #drug, ncRNA
        if kg.kg.nodes[n]["fc"]["sig"] > 0.9:
            return False

    
    return True

def filter_empty_genesets(n, kg):

    if kg.node_type_overlap(n, ["disease", "geneset"]):
        if len(kg._get_predecessors(n, ntype="gene")) < 3:
            return False

        numKgChildren = len(kg._get_predecessors(n, ntype="gene"))
        numAllChildren = len(dkg._get_predecessors(n, ntype="gene"))

        if (numKgChildren/numAllChildren) < 0.5:
            return False
    

    if kg.node_type_overlap(n, ["gene", "ncRNA"]):
        if len(kg.kg.edges(n)) == 0:
            return False

    return True

# %%
all_best_nodes = [x[0] for x in dkg.get_nodes_with_highest_scores(n=3000, score_accessor=lambda x: x["fc_score"], node_filter=geneset_filter)]

for bnodes in [100, 150, 200, 300, 400, 500, 750, 1000, 2000, 2500, 3000]:
    best_nodes = all_best_nodes[0:bnodes]
    for trend in trend2gene:
        trend_overlap = len(set(best_nodes).intersection(trend2gene[trend]))
        pw_overlap = len(set(best_nodes).intersection(trend2pathways[trend]))
        print(bnodes, trend, trend_overlap, trend_overlap/len(trend2gene[trend]), pw_overlap, pw_overlap/len(trend2pathways[trend]))
# Out:
# 100 trend1 5 0.03546099290780142 0 0.0
# 100 trend2 90 0.9 10 1.0
# 100 trend3 5 0.056179775280898875 0 0.0
# 100 trend4 3 0.0379746835443038 0 0.0
# 150 trend1 6 0.0425531914893617 0 0.0
# 150 trend2 93 0.93 10 1.0
# 150 trend3 5 0.056179775280898875 0 0.0
# 150 trend4 3 0.0379746835443038 0 0.0
# 200 trend1 6 0.0425531914893617 0 0.0
# 200 trend2 93 0.93 10 1.0
# 200 trend3 5 0.056179775280898875 0 0.0
# 200 trend4 3 0.0379746835443038 0 0.0
# 300 trend1 6 0.0425531914893617 0 0.0
# 300 trend2 93 0.93 10 1.0
# 300 trend3 5 0.056179775280898875 0 0.0
# 300 trend4 3 0.0379746835443038 0 0.0
# 400 trend1 6 0.0425531914893617 0 0.0
# 400 trend2 93 0.93 10 1.0
# 400 trend3 5 0.056179775280898875 0 0.0
# 400 trend4 3 0.0379746835443038 0 0.0
# 500 trend1 6 0.0425531914893617 0 0.0
# 500 trend2 93 0.93 10 1.0
# 500 trend3 5 0.056179775280898875 0 0.0
# 500 trend4 3 0.0379746835443038 0 0.0
# 750 trend1 6 0.0425531914893617 0 0.0
# 750 trend2 93 0.93 10 1.0
# 750 trend3 5 0.056179775280898875 0 0.0
# 750 trend4 3 0.0379746835443038 0 0.0
# 1000 trend1 6 0.0425531914893617 0 0.0
# 1000 trend2 93 0.93 10 1.0
# 1000 trend3 5 0.056179775280898875 0 0.0
# 1000 trend4 3 0.0379746835443038 0 0.0
# 2000 trend1 6 0.0425531914893617 0 0.0
# 2000 trend2 93 0.93 10 1.0
# 2000 trend3 5 0.056179775280898875 0 0.0
# 2000 trend4 3 0.0379746835443038 0 0.0
# 2500 trend1 6 0.0425531914893617 0 0.0
# 2500 trend2 93 0.93 10 1.0
# 2500 trend3 5 0.056179775280898875 0 0.0
# 2500 trend4 3 0.0379746835443038 0 0.0
# 3000 trend1 6 0.0425531914893617 0 0.0
# 3000 trend2 93 0.93 10 1.0
# 3000 trend3 5 0.056179775280898875 0 0.0
# 3000 trend4 3 0.0379746835443038 0 0.0

# %%
best_nodes = dkg.get_nodes_with_highest_scores(n=300, score_accessor=lambda x: x["fc_score"], node_filter=geneset_filter)       # nodetype="gene",
dkg_small = dkg.subset_kg([x[0] for x in best_nodes])
dkg_small
# Out:
# KGraph KGraph_vs_KGraph_subset with 300 nodes and 829 edges

# %%
best_nodes[-1]
# Out:
# ('CCR5AS', 0.09264633348863312)

# %%
len(set(dkg_small.kg.nodes).intersection(trend2gene["trend2"]))
# Out:
# 93

# %%
dkg_filtered = dkg_small.filter_nodes(filter_empty_genesets)
dkg_filtered = dkg_filtered.filter_nodes(filter_empty_genesets)
dkg_filtered
# Out:
# KGraph KGraph_vs_KGraph_subset_filter_filter with 159 nodes and 700 edges

# %%
len(set(dkg_filtered.kg.nodes).intersection(trend2gene["trend2"]))
# Out:
# 93

# %%
fig, ax = plt.subplots(figsize=(8, 4))
for trend in trend2gene:
    dkg_filtered.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc_score"], nodes=trend2gene[trend], ax=ax, title=trend)
dkg_filtered.plot_node_attribute_histogram(attribute_accessor=lambda x: x["fc_score"], ax=ax, title="all genes")

# %%
_=dkg_filtered.plot_graph(edge_score_accessor=lambda x: x.get("fc_score", 0), node_score_accessor=lambda x: x.get("fc_score", 0), figsize=(15, 15))
# Out:
# /opt/jhub/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dkgModules = dkg_filtered.get_communities_greedymodularity(minEdgeScore=None, resolution=0.5, score_field="fc_score")
dkg_filtered.describe_communities(dkgModules)
# Out:
# Number of communities: 6
# Average community size 26.5
# Median community size 9.0
# Quantile (0,0.25,0.5,0.75,1) community size [  5.    7.5   9.   12.  116. ]

# %%
def evaluate_communities(modules, target_trend, t2g, t2p, p2g):
    allTargetGenes = set()
    singleTargetGenes = set()

    foundPathways = set()

    for x in modules:
        if len(modules[x]) == 1:

            for y in modules[x]:
                if y in t2g[target_trend]:
                    singleTargetGenes.add(y)
            continue
        target_genes = set(modules[x]).intersection(t2g[target_trend])
        allTargetGenes.update(target_genes)

        if len(modules[x])> 0 and len(target_genes) > 0:
            intGenesets = set(t2p[target_trend]).intersection(modules[x])

            foundPathways.update(intGenesets)
            
            print(x, len(modules[x]), len(target_genes), target_genes, intGenesets)

            for pw in intGenesets:
                pwgenes = dkg_filtered._get_predecessors(pw, ntype="gene")
                print(pw, len(pwgenes), len(p2g.get(pw, [])), pwgenes.intersection(target_genes))
            print()

            for n in modules[x]:
                if n in intGenesets:
                    continue
                    
                if "geneset" in dkg_filtered.kg.nodes[n]["type"]:
                    pwgenes = dkg_filtered._get_predecessors(n, ntype="gene")
                    print("OTHER", n, len(pwgenes), pwgenes.intersection(target_genes))

            print()
            print()

    print(len(allTargetGenes))
    print(len(singleTargetGenes))
    print(len(foundPathways), t2p[target_trend].difference(foundPathways))

# %%
evaluate_communities(dkgModules, "trend2", trend2gene, trend2pathways, pathways2genes)
# Out:
# cc_0 116 60 {'ACSM2A', 'MKNK2', 'NPRL2', 'ORMDL3', 'ZNF331', 'HMMR', 'PHGDH', 'HSF1', 'DKC1', 'TGFB1', 'PIM2', 'PALLD', 'MAPKAPK2', 'AR', 'PIM1', 'SMARCA4', 'SRRM1', 'OSBP', 'HDAC3', 'DPY19L3', 'VAMP5', 'GSN', 'DHRS3', 'RAP1GAP2', 'DUSP8', 'ACACB', 'LCK', 'ELL2', 'NRIP1', 'S1PR1', 'E2F1', 'SMAD4', 'BAZ2A', 'STAT3', 'SP1', 'STAT6', 'IRS2', 'PRKAG2', 'CORO1A', 'CREBBP', 'BAX', 'PACSIN2', 'NR1I2', 'PER1', 'ULK2', 'ESR2', 'SREBF1', 'RORA', 'TP53', 'PCK2', 'MAPK3', 'RXRA', 'ETS1', 'LYN', 'ATOX1', 'SPTBN1', 'SKIL', 'RAD51', 'SIRT1', 'UCHL1'} {'IM_SREBF1A_TARGETS', 'MUNSHI_MULTIPLE_MYELOMA_DN', 'MCBRYAN_TERMINAL_END_BUD_DN', 'TSUDA_ALVEOLAR_SOFT_PART_SARCOMA', 'KIM_GERMINAL_CENTER_T_HELPER_DN'}
# IM_SREBF1A_TARGETS 5 5 {'ULK2', 'DPY19L3', 'SREBF1', 'ATOX1', 'ACACB'}
# MUNSHI_MULTIPLE_MYELOMA_DN 8 9 {'NPRL2', 'VAMP5', 'HSF1', 'DKC1', 'SKIL', 'RAD51', 'UCHL1', 'SMARCA4'}
# MCBRYAN_TERMINAL_END_BUD_DN 6 6 {'CORO1A', 'NRIP1', 'PHGDH', 'GSN', 'ETS1', 'LCK'}
# TSUDA_ALVEOLAR_SOFT_PART_SARCOMA 8 23 {'MKNK2', 'PACSIN2', 'PCK2', 'MAPK3', 'PIM1', 'LYN', 'MAPKAPK2', 'PRKAG2'}
# KIM_GERMINAL_CENTER_T_HELPER_DN 12 12 {'ACSM2A', 'ELL2', 'S1PR1', 'PER1', 'OSBP', 'ZNF331', 'RORA', 'SPTBN1', 'DHRS3', 'RAP1GAP2', 'DUSP8', 'IRS2'}
#
#
#
# cc_1 13 8 {'ISCA1', 'CENPP', 'SEMA4D', 'NSD1', 'TSPAN17', 'FAF2', 'ZNF346', 'AGTPBP1'} {'PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN'}
# PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN 8 10 {'ISCA1', 'CENPP', 'SEMA4D', 'NSD1', 'TSPAN17', 'FAF2', 'ZNF346', 'AGTPBP1'}
#
#
#
# cc_2 9 7 {'MT3', 'CIT', 'DNAJB6', 'PAFAH1B1', 'CASP6', 'NRGN', 'PREP'} {'RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN'}
# RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN 10 10 {'MT3', 'CIT', 'DNAJB6', 'PAFAH1B1', 'CASP6', 'NRGN', 'PREP'}
#
#
#
# cc_3 9 8 {'TMEM243', 'SH3BGRL2', 'PDK2', 'PTPRN2', 'APLP2', 'SDK2', 'SIAH1', 'LMBRD1'} {'MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN'}
# MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN 9 10 {'TMEM243', 'SH3BGRL2', 'PDK2', 'PTPRN2', 'APLP2', 'SDK2', 'SIAH1', 'LMBRD1'}
#
#
#
# cc_4 7 6 {'PPT1', 'DAZAP2', 'LGALS9', 'SPINT1', 'CYBA', 'S100A13'} {'IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN'}
# IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN 9 9 {'PPT1', 'DAZAP2', 'LGALS9', 'SPINT1', 'CYBA', 'S100A13'}
#
#
#
# cc_5 5 4 {'RABIF', 'UBE3D', 'GATD3', 'RBBP6'} {'STONER_ESOPHAGEAL_CARCINOGENESIS_DN'}
# STONER_ESOPHAGEAL_CARCINOGENESIS_DN 7 7 {'RABIF', 'UBE3D', 'GATD3', 'RBBP6'}
#
#
#
# 93
# 0
# 10 set()

# %%
def evaluate_communities_detail(kg, modules, target_trend, t2g, t2p, p2g, g2t, fullKG=None, maxlen=30):

    fndElems = []
    for pw in t2p[target_trend]:

        unknownGenes = set()
        stage_counter = Counter()
        #for s,t in dkg.get_node_edges(pw):
        for s in p2g[pw]:
        
            cont_stages = set()
            for x in modules:
                if s in modules[x]:
                    cont_stages.add(x)

            inKG = s in kg.kg.nodes

            if not inKG:
                unknownGenes.add(s)
            
            print(target_trend, pw, s, g2t[s], inKG, cont_stages)
            if len(cont_stages) > 0:
                for x in cont_stages:
                    stage_counter[x] += 1
            else:
                stage_counter["NA"] += 1

        print(stage_counter)
        
        foundCount = sum([stage_counter[x] for x in stage_counter if not x == "NA"])
        notFoundCount = stage_counter["NA"]
        fndElems.append([pw, foundCount, notFoundCount])

        if not fullKG is None:
            for s in unknownGenes:
                print(s, fullKG.kg.nodes[s])
        
        print()

    print()
    print()

    pwSens = set()
    gSens = set()
    pw2sensitivity = defaultdict(set)
    
    for pw in t2p[target_trend]:

        if pw in kg.kg.nodes:
            pwSens.add(pw)

        for g in p2g[pw]:
            
            if g in kg.kg.nodes:
                pw2sensitivity[pw].add(g)
                gSens.add(g)

    pwSensitivity = len(pwSens) / len(t2p[target_trend])
    geneSensitivity = len(gSens) / len(t2g[target_trend])

    pwGeneSensitivity = {}
    for pw in t2p[target_trend]:
        pwGeneSensitivity[pw] = len(pw2sensitivity[pw]) / len(p2g[pw])


    print("Pathway Sensitivity", pwSensitivity)
    print("Gene Sensitivity", geneSensitivity)
    weightedSens = 0
    allGenes = 0
    for pw in pwGeneSensitivity:
        print("PW-Gene Sensitivity", pw, pwGeneSensitivity[pw])

        weightedSens += pwGeneSensitivity[pw] * len(p2g[pw])
        allGenes += len(p2g[pw])

    print("Weighted Sensitivity", weightedSens/allGenes)    
    df = pd.DataFrame.from_records(fndElems, columns=["pathway", "found", "missing"])
    df["pathway"] = df["pathway"].apply(lambda x: x if len(x) < maxlen else x[:maxlen] + "...")
    
    df.plot(x="pathway", kind='bar', stacked=True,
            title='Retained Genes/TFs per pathway for {}'.format(target_trend))
    plt.xticks(rotation=75, ha='right')
    plt.show()

    return df

# %%
pwc = evaluate_communities_detail(dkg_filtered, dkgModules, "trend2", trend2gene, trend2pathways, pathways2genes, gene2type, fullKG=dkg)
# Out:
# trend2 IM_SREBF1A_TARGETS ULK2 {'gene'} True {'cc_0'}
# trend2 IM_SREBF1A_TARGETS DPY19L3 {'gene'} True {'cc_0'}
# trend2 IM_SREBF1A_TARGETS SREBF1 {'gene'} True {'cc_0'}
# trend2 IM_SREBF1A_TARGETS ATOX1 {'gene'} True {'cc_0'}
# trend2 IM_SREBF1A_TARGETS ACACB {'gene'} True {'cc_0'}
# Counter({'cc_0': 5})
#
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN ISCA1 {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN CENPP {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN SEMA4D {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN SFXN1 {'gene'} False set()
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN NSD1 {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN TSPAN17 {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN FAF2 {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN ZNF346 {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN AGTPBP1 {'gene'} True {'cc_1'}
# trend2 PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN C9orf64 {'gene'} False set()
# Counter({'cc_1': 8, 'NA': 2})
# SFXN1 {'type': {'gene', 'measured_expression'}, 'score': 0.004943282993799895, 'name': 'SFXN1', 'source': 'GeneOntology', 'expression': {'mean': 0.3826807220485955, 'sd': 0.1549438035883596, 'perc_expr': 0.0129175124561727, 'median': 0.37772078216654, 'num_measured': 70, 'num_all': 5419}, 'geneset_spec': 0.6300684872384565, 'geneset_spec_zscore': -1.3154804578984982, 'fc': {'score': 0.3227872332019331, 'sig': 0.9255116923970781}, 'fc_score': 0.3227872332019331}
# C9orf64 {'type': {'gene', 'measured_expression'}, 'score': 0.0041233669250876565, 'name': 'C9orf64', 'source': 'kegg', 'expression': {'mean': 0.3920092169657904, 'sd': 0.1572146314409497, 'perc_expr': 0.0105185458571692, 'median': 0.3516475786258867, 'num_measured': 57, 'num_all': 5419}, 'geneset_spec': 0.765312004942569, 'geneset_spec_zscore': -0.4883318333756688, 'fc': {'score': 0.27211902342220573, 'sig': 0.948918304774254}, 'fc_score': 0.27211902342220573}
#
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN PPT1 {'gene'} True {'cc_4'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN BAZ2A {'gene'} True {'cc_0'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN DAZAP2 {'gene'} True {'cc_4'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN TGFB1 {'gene'} True {'cc_0'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN LGALS9 {'gene'} True {'cc_4'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN PIM2 {'gene'} True {'cc_0'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN SPINT1 {'gene'} True {'cc_4'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN CYBA {'gene'} True {'cc_4'}
# trend2 IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN S100A13 {'gene'} True {'cc_4'}
# Counter({'cc_4': 6, 'cc_0': 3})
#
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN NPRL2 {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN VAMP5 {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN HSF1 {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN DKC1 {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN SKIL {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN RAD51 {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN CNOT2 {'gene'} False set()
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN UCHL1 {'gene'} True {'cc_0'}
# trend2 MUNSHI_MULTIPLE_MYELOMA_DN SMARCA4 {'gene'} True {'cc_0'}
# Counter({'cc_0': 8, 'NA': 1})
# CNOT2 {'type': {'gene', 'measured_expression'}, 'source': 'STRING', 'name': 'CNOT2', 'score': 0.005040433625316269, 'expression': {'mean': 0.3793626363276232, 'sd': 0.1450632660341172, 'perc_expr': 0.0132865842406348, 'median': 0.3514829431548278, 'num_measured': 72, 'num_all': 5419}, 'disease_spec': 1.0, 'disease_spec_zscore': 1.0401695678111786, 'geneset_spec': 0.6074311092384048, 'geneset_spec_zscore': -1.4539305395986193, 'fc': {'score': 0.4354226009598201, 'sig': 0.9173556080240916}, 'fc_score': 0.4354226009598201}
#
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN BAX {'gene'} True {'cc_0'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN MT3 {'gene'} True {'cc_2'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN CIT {'gene'} True {'cc_2'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN DNAJB6 {'gene'} True {'cc_2'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN SPTBN1 {'gene'} True {'cc_0'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN RXRA {'gene'} True {'cc_0'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN PAFAH1B1 {'gene'} True {'cc_2'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN CASP6 {'gene'} True {'cc_2'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN NRGN {'gene'} True {'cc_2'}
# trend2 RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN PREP {'gene'} True {'cc_2'}
# Counter({'cc_2': 7, 'cc_0': 3})
#
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN SRRM1 {'gene'} True {'cc_0'}
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN RABIF {'gene'} True {'cc_5'}
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN UBE3D {'gene'} True {'cc_5'}
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN GATD3 {'gene'} True {'cc_5'}
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN RBBP6 {'gene'} True {'cc_5'}
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN HMMR {'gene'} True {'cc_0'}
# trend2 STONER_ESOPHAGEAL_CARCINOGENESIS_DN PALLD {'gene'} True {'cc_0'}
# Counter({'cc_5': 4, 'cc_0': 3})
#
# trend2 MCBRYAN_TERMINAL_END_BUD_DN CORO1A {'gene'} True {'cc_0'}
# trend2 MCBRYAN_TERMINAL_END_BUD_DN NRIP1 {'gene'} True {'cc_0'}
# trend2 MCBRYAN_TERMINAL_END_BUD_DN GSN {'gene'} True {'cc_0'}
# trend2 MCBRYAN_TERMINAL_END_BUD_DN PHGDH {'gene'} True {'cc_0'}
# trend2 MCBRYAN_TERMINAL_END_BUD_DN ETS1 {'gene'} True {'cc_0'}
# trend2 MCBRYAN_TERMINAL_END_BUD_DN LCK {'gene'} True {'cc_0'}
# Counter({'cc_0': 6})
#
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN TMEM243 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN SH3BGRL2 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN ORMDL3 {'gene'} True {'cc_0'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN PLPP3 {'gene'} False set()
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN PDK2 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN APLP2 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN PTPRN2 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN SDK2 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN SIAH1 {'gene'} True {'cc_3'}
# trend2 MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN LMBRD1 {'gene'} True {'cc_3'}
# Counter({'cc_3': 8, 'cc_0': 1, 'NA': 1})
# PLPP3 {'type': {'gene', 'measured_expression'}, 'score': 0.005190037886537213, 'name': 'PLPP3', 'source': 'GeneOntology', 'expression': {'mean': 0.3800650717181801, 'sd': 0.1257870249466331, 'perc_expr': 0.0136556560250968, 'median': 0.387193860776062, 'num_measured': 74, 'num_all': 5419}, 'geneset_spec': 0.5373631112354098, 'geneset_spec_zscore': -1.8824660373076036, 'ncRNA_spec': 1.0, 'ncRNA_spec_zscore': 0.7882999701802029, 'fc': {'score': 0.48417512882913794, 'sig': 0.9080757976396578}, 'fc_score': 0.48417512882913794}
#
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA MKNK2 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA MAPKAPK2 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA AR {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA PIM1 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA HDAC3 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA PPARG {'tf'} False set()
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA E2F1 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA JUN {'gene', 'tf'} False set()
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA SMAD4 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA STAT3 {'tf', 'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA STAT6 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA SP1 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA PRKAG2 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA CREBBP {'tf', 'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA PACSIN2 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA NR1I2 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA ESR2 {'tf'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA TP53 {'tf', 'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA PCK2 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA MAPK3 {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA LYN {'gene'} True {'cc_0'}
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA TWIST1 {'tf'} False set()
# trend2 TSUDA_ALVEOLAR_SOFT_PART_SARCOMA SIRT1 {'tf'} True {'cc_0'}
# Counter({'cc_0': 20, 'NA': 3})
# PPARG {'type': {'gene', 'measured_expression', 'TF'}, 'source': 'STRING', 'name': 'PPARG', 'score': 0.0008373811594097962, 'expression': {'mean': 0.3490591156032075, 'sd': 0.0906611521258339, 'perc_expr': 0.0023989665990035, 'median': 0.3331905770053049, 'num_measured': 13, 'num_all': 5419}, 'disease_spec': 0.5682955907692808, 'disease_spec_zscore': -2.580634911307199, 'geneset_spec': 0.5024260708064981, 'geneset_spec_zscore': -2.0961407880553358, 'ncRNA_spec': 0.6168008593401519, 'ncRNA_spec_zscore': -1.9679111444034973, 'fc': {'score': 0.04570932399775806, 'sig': 0.9929578646812692}, 'fc_score': 0.04570932399775806}
# TWIST1 {'type': {'gene', 'TF'}, 'source': 'STRING', 'name': 'TWIST1', 'score': 0, 'disease_spec': 0.7432228048934796, 'disease_spec_zscore': -1.1134800088375842, 'geneset_spec': 0.5498310889279533, 'geneset_spec_zscore': -1.8062119530155099, 'ncRNA_spec': 0.40626612572559173, 'ncRNA_spec_zscore': -3.4822103982983834, 'fc': {'score': 0.0, 'sig': 1.0}, 'fc_score': 0.0}
# JUN {'type': {'gene', 'measured_expression', 'TF'}, 'source': 'STRING', 'name': 'JUN', 'score': 0.0037212040333297917, 'expression': {'mean': 0.4033040931322849, 'sd': 0.1401406035166485, 'perc_expr': 0.0092267946115519, 'median': 0.4036871356752165, 'num_measured': 50, 'num_all': 5419}, 'disease_spec': 0.8454047241409498, 'disease_spec_zscore': -0.2564566776294455, 'geneset_spec': 0.4299227799874246, 'geneset_spec_zscore': -2.5395705234869497, 'ncRNA_spec': 0.39983975093560165, 'ncRNA_spec_zscore': -3.5284329592157992, 'fc': {'score': 0.2754309849152552, 'sig': 0.9550617245269711}, 'fc_score': 0.2754309849152552}
#
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN ACSM2A {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN ELL2 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN S1PR1 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN PER1 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN OSBP {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN RAP1GAP2 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN ZNF331 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN RORA {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN SPTBN1 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN DHRS3 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN DUSP8 {'gene'} True {'cc_0'}
# trend2 KIM_GERMINAL_CENTER_T_HELPER_DN IRS2 {'gene'} True {'cc_0'}
# Counter({'cc_0': 12})
#
#
#
# Pathway Sensitivity 1.0
# Gene Sensitivity 0.93
# PW-Gene Sensitivity IM_SREBF1A_TARGETS 1.0
# PW-Gene Sensitivity PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN 0.8
# PW-Gene Sensitivity IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN 1.0
# PW-Gene Sensitivity MUNSHI_MULTIPLE_MYELOMA_DN 0.8888888888888888
# PW-Gene Sensitivity RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN 1.0
# PW-Gene Sensitivity STONER_ESOPHAGEAL_CARCINOGENESIS_DN 1.0
# PW-Gene Sensitivity MCBRYAN_TERMINAL_END_BUD_DN 1.0
# PW-Gene Sensitivity MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN 0.9
# PW-Gene Sensitivity TSUDA_ALVEOLAR_SOFT_PART_SARCOMA 0.8695652173913043
# PW-Gene Sensitivity KIM_GERMINAL_CENTER_T_HELPER_DN 1.0
# Weighted Sensitivity 0.9306930693069307

# %%
pd.set_option('display.max_rows', None)
display(simulatedGenes[simulatedGenes.trend=="trend2"].head(None))
pd.set_option('display.max_rows', 50)
# Out:
#      wildtype  stage1  stage2  stage3  \
# 144         8       2       1       1
# 145         8       2       1       1
# 146         8       2       1       1
# 147         8       2       1       1
# 148         8       2       1       1
# 149         8       2       1       1
# 150         8       2       1       1
# 151         8       2       1       1
# 152         8       2       1       1
# 153         8       2       1       1
# 154         8       2       1       1
# 155         8       2       1       1
# 156         8       2       1       1
# 157         8       2       1       1
# 158         8       2       1       1
# 159         8       2       1       1
# 160         8       2       1       1
# 161         8       2       1       1
# 162         8       2       1       1
# 163         8       2       1       1
# 164         8       2       1       1
# 165         8       2       1       1
# 166         8       2       1       1
# 167         8       2       1       1
# 168         8       2       1       1
# 169         8       2       1       1
# 170         8       2       1       1
# 171         8       2       1       1
# 172         8       2       1       1
# 173         8       2       1       1
# 174         8       2       1       1
# 175         8       2       1       1
# 176         8       2       1       1
# 177         8       2       1       1
# 178         8       2       1       1
# 179         8       2       1       1
# 180         8       2       1       1
# 181         8       2       1       1
# 182         8       2       1       1
# 183         8       2       1       1
# 184         8       2       1       1
# 185         8       2       1       1
# 186         8       2       1       1
# 187         8       2       1       1
# 188         8       2       1       1
# 189         8       2       1       1
# 190         8       2       1       1
# 191         8       2       1       1
# 192         8       2       1       1
# 193         8       2       1       1
# 194         8       2       1       1
# 195         8       2       1       1
# 196         8       2       1       1
# 197         8       2       1       1
# 198         8       2       1       1
# 199         8       2       1       1
# 200         8       2       1       1
# 201         8       2       1       1
# 202         8       2       1       1
# 203         8       2       1       1
# 204         8       2       1       1
# 205         8       2       1       1
# 206         8       2       1       1
# 207         8       2       1       1
# 208         8       2       1       1
# 209         8       2       1       1
# 210         8       2       1       1
# 211         8       2       1       1
# 212         8       2       1       1
# 213         8       2       1       1
# 214         8       2       1       1
# 215         8       2       1       1
# 216         8       2       1       1
# 217         8       2       1       1
# 218         8       2       1       1
# 219         8       2       1       1
# 220         8       2       1       1
# 221         8       2       1       1
# 222         8       2       1       1
# 223         8       2       1       1
# 224         8       2       1       1
# 225         8       2       1       1
# 226         8       2       1       1
# 227         8       2       1       1
# 228         8       2       1       1
# 229         8       2       1       1
# 230         8       2       1       1
# 231         8       2       1       1
# 232         8       2       1       1
# 233         8       2       1       1
# 234         8       2       1       1
# 235         8       2       1       1
# 236         8       2       1       1
# 237         8       2       1       1
# 238         8       2       1       1
# 239         8       2       1       1
# 240         8       2       1       1
# 241         8       2       1       1
# 242         8       2       1       1
# 243         8       2       1       1
# 244         8       2       1       1
#
#                                            geneset   trend element_type  \
# 144       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 145       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 146       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 147       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 148       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 149       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 150       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 151       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 152       IIZUKA_LIVER_CANCER_PROGRESSION_G2_G3_DN  trend2         gene
# 153                             IM_SREBF1A_TARGETS  trend2         gene
# 154                             IM_SREBF1A_TARGETS  trend2         gene
# 155                             IM_SREBF1A_TARGETS  trend2         gene
# 156                             IM_SREBF1A_TARGETS  trend2         gene
# 157                             IM_SREBF1A_TARGETS  trend2         gene
# 158                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 159                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 160                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 161                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 162                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 163                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 164                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 165                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 166                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 167                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 168                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 169                KIM_GERMINAL_CENTER_T_HELPER_DN  trend2         gene
# 170                    MCBRYAN_TERMINAL_END_BUD_DN  trend2         gene
# 171                    MCBRYAN_TERMINAL_END_BUD_DN  trend2         gene
# 172                    MCBRYAN_TERMINAL_END_BUD_DN  trend2         gene
# 173                    MCBRYAN_TERMINAL_END_BUD_DN  trend2         gene
# 174                    MCBRYAN_TERMINAL_END_BUD_DN  trend2         gene
# 175                    MCBRYAN_TERMINAL_END_BUD_DN  trend2         gene
# 176        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 177        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 178        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 179        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 180        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 181        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 182        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 183        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 184        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 185        MONTERO_THYROID_CANCER_POOR_SURVIVAL_DN  trend2         gene
# 186                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 187                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 188                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 189                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 190                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 191                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 192                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 193                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 194                     MUNSHI_MULTIPLE_MYELOMA_DN  trend2         gene
# 195        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 196        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 197        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 198        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 199        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 200        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 201        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 202        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 203        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 204        PETRETTO_LEFT_VENTRICLE_MASS_QTL_CIS_DN  trend2         gene
# 205  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 206  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 207  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 208  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 209  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 210  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 211  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 212  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 213  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 214  RAMPON_ENRICHED_LEARNING_ENVIRONMENT_EARLY_DN  trend2         gene
# 215            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 216            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 217            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 218            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 219            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 220            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 221            STONER_ESOPHAGEAL_CARCINOGENESIS_DN  trend2         gene
# 222               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 223               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 224               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 225               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 226               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 227               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 228               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 229               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2         gene
# 230               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 231               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 232               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 233               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 234               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 235               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 236               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 237               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 238               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 239               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 240               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 241               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 242               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 243               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
# 244               TSUDA_ALVEOLAR_SOFT_PART_SARCOMA  trend2           tf
#
#          gene
# 144     BAZ2A
# 145      CYBA
# 146    DAZAP2
# 147    LGALS9
# 148      PIM2
# 149      PPT1
# 150   S100A13
# 151    SPINT1
# 152     TGFB1
# 153     ACACB
# 154     ATOX1
# 155   DPY19L3
# 156    SREBF1
# 157      ULK2
# 158    ACSM2A
# 159     DHRS3
# 160     DUSP8
# 161      ELL2
# 162      IRS2
# 163      OSBP
# 164      PER1
# 165  RAP1GAP2
# 166      RORA
# 167     S1PR1
# 168    SPTBN1
# 169    ZNF331
# 170    CORO1A
# 171      ETS1
# 172       GSN
# 173       LCK
# 174     NRIP1
# 175     PHGDH
# 176     APLP2
# 177    LMBRD1
# 178    ORMDL3
# 179      PDK2
# 180     PLPP3
# 181    PTPRN2
# 182      SDK2
# 183  SH3BGRL2
# 184     SIAH1
# 185   TMEM243
# 186     CNOT2
# 187      DKC1
# 188      HSF1
# 189     NPRL2
# 190     RAD51
# 191      SKIL
# 192   SMARCA4
# 193     UCHL1
# 194     VAMP5
# 195   AGTPBP1
# 196   C9orf64
# 197     CENPP
# 198      FAF2
# 199     ISCA1
# 200      NSD1
# 201    SEMA4D
# 202     SFXN1
# 203   TSPAN17
# 204    ZNF346
# 205       BAX
# 206     CASP6
# 207       CIT
# 208    DNAJB6
# 209       MT3
# 210      NRGN
# 211  PAFAH1B1
# 212      PREP
# 213      RXRA
# 214    SPTBN1
# 215     GATD3
# 216      HMMR
# 217     PALLD
# 218     RABIF
# 219     RBBP6
# 220     SRRM1
# 221     UBE3D
# 222       LYN
# 223     MAPK3
# 224  MAPKAPK2
# 225     MKNK2
# 226   PACSIN2
# 227      PCK2
# 228      PIM1
# 229    PRKAG2
# 230     HDAC3
# 231       SP1
# 232     SIRT1
# 233     STAT3
# 234       JUN
# 235      E2F1
# 236     STAT6
# 237     PPARG
# 238      TP53
# 239    CREBBP
# 240     SMAD4
# 241     NR1I2
# 242        AR
# 243    TWIST1
# 244      ESR2
